# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_and_process_signal():
    """
    Generates a composite signal, splits it into monotonic segments,
    and plots the results.
    """
    # --- 1. Signal Parameters ---
    # Define the characteristics of the sine wave and the linear signal.
    amplitude = 2.0       # Amplitude of the sine wave
    frequency = 0.625       # Frequency (not directly used for y vs x plot, but for context)
    wavelength = 1.6   # Wavelength (lambda) of the sine wave
    num_cycles = 3       # Number of sine wave cycles to generate
    slope_degrees = 45.0  # Slope of the linear signal in degrees

    # --- 2. Generate the Signal Data ---
    # The signal is the sum of a sine wave and a linear function.
    # y(x) = (Amplitude * sin(2*pi/wavelength * x)) + (slope * x)

    # Convert the slope from degrees to a gradient (m = tan(theta))
    slope_gradient = np.tan(np.deg2rad(slope_degrees))

    # Calculate the wave number 'k' for the sine wave
    # k = 2 * pi / wavelength
    k = 2 * np.pi / wavelength

    # Determine the total length of the x-axis
    x_max = num_cycles * wavelength

    # Create a dense array of x-values for a smooth curve.
    # We'll use 500 points per cycle for high resolution.
    num_points = int(num_cycles * 100000)
    x_values = np.linspace(0, x_max, num_points)

    # Calculate the corresponding y-values for the composite signal
    y_sine = amplitude * np.sin(k * x_values)
    y_linear = slope_gradient * x_values
    y_values = y_sine + y_linear

    print("--- Original Signal Generated ---")
    print(f"Generated {num_points} data points over {num_cycles} cycles.")
    print(f"X-values range from {x_values.min():.2f} to {x_values.max():.2f}")
    print(f"Y-values range from {y_values.min():.2f} to {y_values.max():.2f}\n")


    # --- 3. Split the Signal into Monotonic Segments ---
    # We split the array wherever the signal's direction changes (i.e., at local
    # minima and maxima). This happens where the y-values stop increasing and start
    # decreasing, or vice-versa.

    # Find the differences between consecutive y-values
    y_diff = np.diff(y_values)

    # Determine the sign of the difference (1 for increasing, -1 for decreasing)
    y_direction = np.sign(y_diff)

    # Find the indices where the direction changes. We add 1 to align the index
    # with the actual point of the extremum in the original y_values array.
    split_indices_raw = np.where(np.diff(y_direction) != 0)[0] + 1

    # Create a final list of split points, including the start and end of the signal
    split_indices = np.concatenate(([0], split_indices_raw, [len(x_values) - 1]))

    # Create lists to hold the split x and y arrays
    split_x_arrays = []
    split_y_arrays = []

    print(f"--- Splitting Signal ---")
    print(f"Found {len(split_indices_raw)} turning points (extrema).")
    print(f"Splitting into {len(split_indices)-1} monotonic segments.\n")

    for i in range(len(split_indices) - 1):
        start_index = split_indices[i]
        # We add 1 to the end_index to ensure the segments overlap at the split
        # point, making the final plot look continuous.
        end_index = split_indices[i+1] + 1

        # Slice the main arrays to create the new segment
        x_segment = x_values[start_index:end_index]
        y_segment = y_values[start_index:end_index]

        # Add the new segments to our lists
        split_x_arrays.append(x_segment)
        split_y_arrays.append(y_segment)

    # --- 4. Print the Split Vectors ---
    # Iterate through the generated segments and print them.
    for i, (x_seg, y_seg) in enumerate(zip(split_x_arrays, split_y_arrays)):
        print(f"--- Vector for Segment {i+1} ---")
        # To keep the output clean, we can show the first few values
        print(f"X values first: {x_seg[0:2]} last:{x_seg[-3:-1]} ")
        print(f"Y values first: {y_seg[0:2]} last:{y_seg[-3:-1]} ")
        print(f"Segment contains {len(x_seg)} points.\n")


    # --- 5. Plot the Results ---
    # Create a plot and draw each segment with a different color.
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, ax = plt.subplots(figsize=(15, 8))
    ax.plot(x_values,y_values)

    for i in range(len(split_x_arrays)):
        ax.plot(split_x_arrays[i], split_y_arrays[i],
                label=f'Segment {i+1}', linewidth=2.5)

    # Add labels, title, and a legend for clarity
    ax.set_title(f'Composite Signal (Sine + Linear) Split into {len(split_x_arrays)} Monotonic Segments', fontsize=16)
    ax.set_xlabel('X-axis', fontsize=12)
    ax.set_ylabel('Y-axis (Signal Value)', fontsize=12)
    ax.legend(title='Signal Segments')
    fig.tight_layout()

    # Display the plot
    plt.show()

    K = 3
    # Now, `y_composite` holds the correct signal data you want to analyze.
    # You can proceed to find the values at specific points or plot it.
    # For example, to check our work:
    t_peak1 = wavelength / 4
    val_peak1 = amplitude * np.sin(k * t_peak1) + slope_gradient * t_peak1
    print(f"Value at peak of cycle 1 (t={t_peak1:.2f}s): {val_peak1:.4f}") # Should be 2.4

    t_trough3 = (K - 1) * wavelength + (3 * wavelength / 4)
    val_trough3 = amplitude * np.sin(k * t_trough3) + slope_gradient * t_trough3
    print(f"Value at trough of cycle 3 (t={t_trough3:.2f}s): {val_trough3:.4f}") # Should be 2.4


if __name__ == '__main__':
    generate_and_process_signal()
# Out:
# --- Original Signal Generated ---
# Generated 3000 data points over 3 cycles.
# X-values range from 0.00 to 4.80
# Y-values range from -0.82 to 5.62
#
# --- Splitting Signal ---
# Found 6 turning points (extrema).
# Splitting into 7 monotonic segments.
#
# --- Vector for Segment 1 ---
# X values first: [0.         0.00160053] last:[0.42894298 0.43054351]
# Y values first: [0.         0.01417101] last:[2.41603855 2.41617417]
# Segment contains 271 points.
#
# --- Vector for Segment 2 ---
# X values first: [0.43214405 0.43374458] last:[1.16358786 1.1651884 ]
# Y values first: [2.41623134 2.41621013] last:[-0.81600077 -0.81615247]
# Segment contains 460 points.
#
# --- Vector for Segment 3 ---
# X values first: [1.16678893 1.16838946] last:[2.02947649 2.03107703]
# Y values first: [-0.8162259  -0.81622099] last:[4.01609248 4.01620194]
# Segment contains 542 points.
#
# --- Vector for Segment 4 ---
# X values first: [2.03267756 2.03427809] last:[2.76412137 2.76572191]
# Y values first: [4.01623297 4.01618565] last:[0.78393997 0.78381435]
# Segment contains 460 points.
#
# --- Vector for Segment 5 ---
# X values first: [2.76732244 2.76892297] last:[3.63001    3.63161054]
# Y values first: [0.78376703 0.78379806] last:[5.61613768 5.61622099]
# Segment contains 542 points.
#
# --- Vector for Segment 6 ---
# X values first: [3.63321107 3.6348116 ] last:[4.36465488 4.36625542]
# Y values first: [5.6162259  5.61615247] last:[2.3838894  2.38378987]
# Segment contains 460 points.
#
# --- Vector for Segment 7 ---
# X values first: [4.36785595 4.36945649] last:[4.79679893 4.79839947]
# Y values first: [2.38376866 2.38382583] last:[4.77165847 4.78582899]
# Segment contains 271 points.
# Value at peak of cycle 1 (t=0.40s): 2.4000
# Value at trough of cycle 3 (t=4.40s): 2.4000

# %%
import numpy as np
import csv
# Assuming you will use matplotlib to plot, though it's not in the original snippet.
# import matplotlib.pyplot as plt

def generate_and_plot_signal():
    """
    Generates a composite signal (sine + linear) based on our discussion
    and prepares it for analysis or plotting.
    """
    # --- 1. Signal Parameters (Matching our discussion) ---
    # These parameters are based on our conversation to make the peak of cycle 1
    # match the trough of cycle 3.

    amplitude = 2.0       # Corresponds to 'A' in our formulas
    slope_degrees = 45.0  # The angle of the linear ramp
    num_cycles = 10       # Number of sine wave cycles to generate

    # --- 2. Calculate Derived Parameters (The "Fix") ---
    # Here, we use the formulas we derived to get the exact parameters
    # that will make the condition (Peak of C1 == Trough of C3) true.

    # Convert slope from degrees to a gradient 'm'
    # m = tan(theta). For 45 degrees, this is exactly 1.
    slope_m = np.tan(np.deg2rad(slope_degrees))

    # We are targeting the 3rd cycle, so K=3
    K = 3

    # Calculate the exact FREQUENCY 'f' needed using our formula:
    # f_K = (m / 2A) * (K - 0.5)
    frequency_f = (slope_m / (2 * amplitude)) * (K - 0.5)
    # This will calculate f = (1 / 4) * 2.5 = 0.625 Hz

    # Calculate the exact PERIOD 'T' from the frequency. This is the crucial
    # value that was being misinterpreted as "wavelength".
    # T = 1 / f
    period_T = 1 / frequency_f
    # This will calculate T = 1 / 0.625 = 1.6 seconds

    print(f"Calculated Slope 'm': {slope_m:.4f}")
    print(f"Required Frequency 'f' for K=3: {frequency_f:.4f} Hz")
    print(f"Required Period 'T': {period_T:.4f} seconds")

    # --- 3. Generate the Signal Data (in the TIME domain) ---
    # The signal is a function of TIME 't'.
    # C(t) = A * sin(2*pi/T * t) + m*t

    # Angular frequency 'omega' (ω) = 2 * pi / T
    omega = 2 * np.pi / period_T

    # Determine the total time for the x-axis
    t_max = num_cycles * period_T

    # Create a dense array of time-values for a smooth curve.
    num_points = int(num_cycles * 1000)
    t_values = np.linspace(0, t_max, num_points)

    # --- THIS IS THE CRITICAL FIX ---
    # Calculate the two separate components of the signal
    y_sine = amplitude * np.sin(omega * t_values)
    y_linear = slope_m * t_values

    # Add them together to create the final composite signal
    y_composite = y_sine + y_linear

    # Now, `y_composite` holds the correct signal data you want to analyze.
    # You can proceed to find the values at specific points or plot it.
    # For example, to check our work:
    t_peak1 = period_T / 4
    val_peak1 = amplitude * np.sin(omega * t_peak1) + slope_m * t_peak1
    print(f"Value at peak of cycle 1 (t={t_peak1:.2f}s): {val_peak1:.4f}") # Should be 2.4

    t_trough3 = (K - 1) * period_T + (3 * period_T / 4)
    val_trough3 = amplitude * np.sin(omega * t_trough3) + slope_m * t_trough3
    print(f"Value at trough of cycle 3 (t={t_trough3:.2f}s): {val_trough3:.4f}") # Should be 2.4

        # --- 4. Save the Data to CSV ---
    # Define the name of the output file
    filename = "composite_signal_data.csv"

    try:
        # Open the file in 'write' mode. `newline=''` is a best practice.
        with open(filename, 'w', newline='') as csvfile:
            # Create a csv writer object
            csv_writer = csv.writer(csvfile)

            # Write the header row
            csv_writer.writerow(['Time (s)', 'Amplitude'])

            # Use zip to pair each time value with its amplitude value
            # and write all rows to the file
            csv_writer.writerows(zip(t_values, y_composite))

        print(f"\nData successfully saved to '{filename}'")

    except IOError as e:
        print(f"\nError saving file: {e}")


    return t_values, y_composite

# --- Run the function ---
if __name__ == '__main__':
    t, y = generate_and_plot_signal()
    # You can add plotting code here, e.g.:
    plt.figure(figsize=(12, 6))
    plt.plot(t, y)
    plt.title("Corrected Composite Signal (Sine + Linear)")
    plt.xlabel("Time (seconds)")
    plt.ylabel("Amplitude")
    plt.grid(True)
    plt.show()
# Out:
# Calculated Slope 'm': 1.0000
# Required Frequency 'f' for K=3: 0.6250 Hz
# Required Period 'T': 1.6000 seconds
# Value at peak of cycle 1 (t=0.40s): 2.4000
# Value at trough of cycle 3 (t=4.40s): 2.4000
#
# Data successfully saved to 'composite_signal_data.csv'

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_and_process_signal_by_derivative():
    """
    Generates a composite signal and splits it at its true turning points,
    which are found by setting the function's derivative to zero.
    """
    # --- 1. Signal Parameters ---
    amplitude = 2.0
    frequency = 0.619885
    wave_speed = 1.0
    num_cycles = 6
    slope_degrees =45.0

    # --- 2. Calculate Spatial & Signal Properties ---
    if frequency <= 0:
        raise ValueError("Frequency must be a positive number.")
    wavelength = wave_speed / frequency
    k = 2 * np.pi / wavelength  # Wave number
    slope_gradient = np.tan(np.deg2rad(slope_degrees)) # Slope 'm'

    print(f"--- Wave Properties ---")
    print(f"Calculated Wavelength: {wavelength:.4f}")
    print(f"Wave Number (k): {k:.4f}")
    print(f"Slope (m): {slope_gradient:.4f}\n")

    # --- 3. Generate the Signal Data ---
    x_max = num_cycles * wavelength
    num_points = int(num_cycles * 100000)
    x_values = np.linspace(0, x_max, num_points)
    y_sine = amplitude * np.sin(k * x_values)
    y_linear = slope_gradient * x_values
    y_values = y_sine + y_linear

    # --- 4. Split Signal using Calculus (Derivative Method) ---
    # The turning points (extrema) occur where the derivative of the function is 0.
    # Function: y(x) = A*sin(kx) + mx
    # Derivative: y'(x) = A*k*cos(kx) + m
    # Set derivative to 0: A*k*cos(kx) + m = 0  =>  cos(kx) = -m / (A*k)

    cos_val = -slope_gradient / (amplitude * k)

    # The arccos function is only defined for inputs between -1 and 1.
    if abs(cos_val) > 1:
        print("No turning points exist. The linear slope is too steep.")
        # If no turning points, we can treat the whole signal as one segment
        split_x_arrays = [x_values]
        split_y_arrays = [y_values]
        split_x_locations = []
    else:
        # Find the principal angle (in radians) for the phase.
        # This gives us the first solution for kx.
        principal_angle = np.arccos(cos_val)

        split_x_locations = []
        n = 0
        while True:
            # The general solution for arccos gives two sets of angles per 2*pi cycle.
            # Solution 1: kx = 2*n*pi + principal_angle
            x_loc1 = (2 * n * np.pi + principal_angle) / k
            # Solution 2: kx = 2*(n+1)*pi - principal_angle
            x_loc2 = (2 * (n + 1) * np.pi - principal_angle) / k

            # Add the locations if they are within our x-range
            stop_adding = True
            if x_loc1 < x_max:
                split_x_locations.append(x_loc1)
                stop_adding = False
            if x_loc2 < x_max:
                split_x_locations.append(x_loc2)
                stop_adding = False
            
            if stop_adding:
                break
            n += 1
        
        # Sort the locations as they are generated out of order
        split_x_locations.sort()
        
        # Find the indices in our x_values array that are closest to these exact locations
        split_indices_raw = np.searchsorted(x_values, split_x_locations)
        split_indices = np.concatenate(([0], split_indices_raw, [len(x_values) - 1]))

        split_x_arrays = []
        split_y_arrays = []

        for i in range(len(split_indices) - 1):
            start_index = split_indices[i]
            end_index = split_indices[i+1] + 1
            if i == len(split_indices) - 2:
                end_index = split_indices[i+1]
            x_segment = x_values[start_index:end_index]
            y_segment = y_values[start_index:end_index]
            split_x_arrays.append(x_segment)
            split_y_arrays.append(y_segment)

    print(f"--- Splitting Signal by Derivative ---")
    print(f"cos(kx) solved for: {cos_val:.4f}")
    print(f"Calculated {len(split_x_locations)} split points (extrema).")
    print(f"Splitting into {len(split_x_arrays)} segments.\n")

    # --- 5. Print the Split Vectors ---
    for i, (x_seg, y_seg) in enumerate(zip(split_x_arrays, split_y_arrays)):
        print(f"--- Vector for Segment {i+1} ---")
        print(f"Segment contains {len(x_seg)} points. X starts at {x_seg[0]:.2f}, Y starts at {y_seg[0]:.2f}")
        print(f"X values first: {x_seg[0:2]} last:{x_seg[-3:-1]} ")
        print(f"Y values first: {y_seg[0:2]} last:{y_seg[-3:-1]} ")

    # --- 6. Plot the Results ---
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, ax = plt.subplots(figsize=(15, 8))

    for i in range(len(split_x_arrays)):
        ax.plot(split_x_arrays[i], split_y_arrays[i],
                label=f'Segment {i+1}', linewidth=2.5)

    ax.vlines(split_x_locations, ymin=y_values.min(), ymax=y_values.max(),
              colors='red', linestyles=':', label='True Extrema (y\'=0)')

    ax.set_title(f'Composite Signal (Split by Finding Extrema via Derivative)', fontsize=16)
    ax.set_xlabel('X-axis (Distance)', fontsize=12)
    ax.set_ylabel('Y-axis (Signal Value)', fontsize=12)
    ax.legend(title='Signal Segments')
    fig.tight_layout()

    plt.show()

if __name__ == '__main__':
    generate_and_process_signal_by_derivative()
# Out:
# --- Wave Properties ---
# Calculated Wavelength: 1.6132
# Wave Number (k): 3.8949
# Slope (m): 1.0000
#
# --- Splitting Signal by Derivative ---
# cos(kx) solved for: -0.1284
# Calculated 12 split points (extrema).
# Splitting into 13 segments.
#
# --- Vector for Segment 1 ---
# Segment contains 27050 points. X starts at 0.00, Y starts at 0.00
# X values first: [0.00000000e+00 1.61320514e-05] last:[0.43632359 0.43633973]
# Y values first: [0.        0.0001418] last:[2.41980338 2.41980339]
# --- Vector for Segment 2 ---
# Segment contains 45904 points. X starts at 0.44, Y starts at 2.42
# X values first: [0.43635586 0.43637199] last:[1.17683315 1.17684928]
# Y values first: [2.41980339 2.41980338] last:[-0.80660093 -0.80660094]
# --- Vector for Segment 3 ---
# Segment contains 54098 points. X starts at 1.18, Y starts at -0.81
# X values first: [1.17686541 1.17688154] last:[2.04952873 2.04954486]
# Y values first: [-0.80660094 -0.80660093] last:[4.03300583 4.03300584]
# --- Vector for Segment 4 ---
# Segment contains 45903 points. X starts at 2.05, Y starts at 4.03
# X values first: [2.049561   2.04957713] last:[2.79002215 2.79003829]
# Y values first: [4.03300584 4.03300583] last:[0.80660152 0.80660151]
# --- Vector for Segment 5 ---
# Segment contains 54099 points. X starts at 2.79, Y starts at 0.81
# X values first: [2.79005442 2.79007055] last:[3.66273387 3.66275   ]
# Y values first: [0.80660151 0.80660151] last:[5.64620828 5.64620829]
# --- Vector for Segment 6 ---
# Segment contains 45903 points. X starts at 3.66, Y starts at 5.65
# X values first: [3.66276613 3.66278226] last:[4.40322729 4.40324342]
# Y values first: [5.64620828 5.64620828] last:[2.41980397 2.41980396]
# --- Vector for Segment 7 ---
# Segment contains 54099 points. X starts at 4.40, Y starts at 2.42
# X values first: [4.40325955 4.40327569] last:[5.27593901 5.27595514]
# Y values first: [2.41980396 2.41980396] last:[7.25941073 7.25941073]
# --- Vector for Segment 8 ---
# Segment contains 45903 points. X starts at 5.28, Y starts at 7.26
# X values first: [5.27597127 5.2759874 ] last:[6.01643243 6.01644856]
# Y values first: [7.25941073 7.25941072] last:[4.03300642 4.03300641]
# --- Vector for Segment 9 ---
# Segment contains 54099 points. X starts at 6.02, Y starts at 4.03
# X values first: [6.01646469 6.01648082] last:[6.88914414 6.88916028]
# Y values first: [4.03300641 4.03300641] last:[8.87261318 8.87261318]
# --- Vector for Segment 10 ---
# Segment contains 45903 points. X starts at 6.89, Y starts at 8.87
# X values first: [6.88917641 6.88919254] last:[7.62963757 7.6296537 ]
# Y values first: [8.87261318 8.87261317] last:[5.64620886 5.64620886]
# --- Vector for Segment 11 ---
# Segment contains 54098 points. X starts at 7.63, Y starts at 5.65
# X values first: [7.62966983 7.62968596] last:[8.50233315 8.50234928]
# Y values first: [5.64620886 5.64620887] last:[10.48581562 10.48581563]
# --- Vector for Segment 12 ---
# Segment contains 45904 points. X starts at 8.50, Y starts at 10.49
# X values first: [8.50236541 8.50238155] last:[9.2428427  9.24285884]
# Y values first: [10.48581563 10.48581563] last:[7.25941131 7.25941131]
# --- Vector for Segment 13 ---
# Segment contains 27048 points. X starts at 9.24, Y starts at 7.26
# X values first: [9.24287497 9.2428911 ] last:[9.6791663  9.67918243]
# Y values first: [7.25941131 7.25941132] last:[9.67878931 9.6789311 ]

# %%
import numpy as np
from scipy.optimize import fsolve # The numerical solver

def find_true_matching_frequency():
    """
    Finds the frequency 'f' where the value at the true peak of the first
    cycle equals the value at the true trough of a subsequent cycle 'N'.
    """
    # --- 1. Define Known Parameters ---
    A = 2 # Amplitude
    m = 1.0  # Slope
    N = 3 # Target subsequent cycle

    # --- 2. Define the Error Function to Solve ---
    # We need to find the root of this function, i.e., where error_function(omega) = 0.
    # This is a direct implementation of the transcendental equation derived above.
    def error_function(omega, A_param, m_param, N_param):
        # The equation is only valid if A*omega > m, otherwise we get a math error.
        if m_param >= A_param * omega:
            return 1e9 # Return a large number if parameters are invalid

        # Calculate the common terms
        sqrt_term = np.sqrt(1 - (m_param**2 / (A_param**2 * omega**2)))
        arccos_term = np.arccos(-m_param / (A_param * omega))

        # Left-hand side of the equation
        LHS = 2 * A_param * sqrt_term

        # Right-hand side of the equation
        RHS = (m_param / omega) * (2 * np.pi * N_param - 2 * arccos_term)

        return LHS - RHS

    # --- 3. Find the Solution Numerically ---
    # We need an initial guess for the solver. Let's use the frequency from
    # our previous, simpler model as a starting point.
    f_simple_guess = (m / (2 * A)) * (N - 0.5)
    omega_guess = 2 * np.pi * f_simple_guess

    # Use fsolve to find the omega that makes our error_function zero.
    # The `args` parameter passes the constants to our function.
    omega_solution, = fsolve(error_function, omega_guess, args=(A, m, N))

    # Convert the angular frequency solution back to Hz
    f_solution = omega_solution / (2 * np.pi)

    # --- 4. Print the Results ---
    print("--- Solving for True Turning Point Match ---")
    print(f"Parameters: A={A}, m={m}, Target Cycle N={N}")
    print(f"Initial Guess (from simple model): f = {f_simple_guess:.6f} Hz")
    print("-" * 40)
    print(f"Numerical Solution for Angular Frequency (ω): {omega_solution:.6f} rad/s")
    print(f"Precise Frequency Solution (f): {f_solution:.6f} Hz")

    return f_solution

# --- Run the Solver ---
if __name__ == '__main__':
    precise_frequency = find_true_matching_frequency()
# Out:
# --- Solving for True Turning Point Match ---
# Parameters: A=2, m=1.0, Target Cycle N=3
# Initial Guess (from simple model): f = 0.625000 Hz
# ----------------------------------------
# Numerical Solution for Angular Frequency (ω): 3.894853 rad/s
# Precise Frequency Solution (f): 0.619885 Hz

# %%
import numpy as np

def find_N_for_frequency():
    """
    For a given frequency 'f', calculates the effective cycle number 'N'
    where the value at the true peak of the first cycle equals the value
    at the true trough of cycle 'N'.
    """
    # --- 1. Define Known Parameters ---
    A = 1.226  # Amplitude
    m = 1.0  # Slope
    f = 1.235590e+3  # Input Frequency in Hz (using the result from our last script as an example)

    # --- 2. Calculate N using the derived formula ---
    # Convert frequency in Hz to angular frequency in rad/s
    omega = 2 * np.pi * f

    # Validity Check: The slope 'm' cannot be greater than the sine wave's
    # maximum slope 'A*omega', otherwise no turning points exist.
    if m >= A * omega:
        print(f"\nError: Invalid Parameters. The slope 'm' ({m}) is too high for the given")
        print(f"amplitude and frequency. 'm' must be less than 'A*omega' ({A*omega:.4f}).")
        return None

    # Calculate the two main parts of the formula
    term1 = (A * omega) / (np.pi * m) * np.sqrt(1 - (m**2 / (A**2 * omega**2)))
    term2 = (1 / np.pi) * np.arccos(-m / (A * omega))

    # The final result for N
    N_solution = term1 + term2

    # --- 3. Print the Results ---
    print("--- Solving for N for a Given Frequency ---")
    print(f"Parameters: A={A}, m={m}, Input Frequency f={f:.24f} Hz")
    print("-" * 40)
    print(f"Effective Cycle Number (N): {N_solution:.24f}")
    print("\nNote: 'N' is not expected to be an integer. It represents the point")
    print("in the signal's evolution where the condition is met.")

    return N_solution

# --- Run the Calculator ---
if __name__ == '__main__':
    N_result = find_N_for_frequency()
# Out:
# --- Solving for N for a Given Frequency ---
# Parameters: A=1.226, m=1.0, Input Frequency f=1235.589999999999918145476840 Hz
# ----------------------------------------
# Effective Cycle Number (N): 3030.166696721506923495326191
#
# Note: 'N' is not expected to be an integer. It represents the point
# in the signal's evolution where the condition is met.

# %%
import numpy as np
from scipy.optimize import fsolve

def find_amplitude_for_N():
    """
    Finds the Amplitude 'A' required for the value at the true peak of the
    first cycle to equal the value at the true trough of a given cycle 'N',
    for a known frequency and slope.
    """
    # --- 1. Define Known Parameters ---
    m = 1.0          # Slope
    f = 1.235590e+3     # Known Frequency in Hz
    N = 3030            # Target integer cycle

    # --- 2. Define the Error Function to Solve for 'A' ---
    # We need to find the value of 'A' that makes this function return 0.
    # The unknown variable here is 'A_param'.
    def error_function(A_param, m_param, omega_param, N_param):
        # The equation is only valid if A*omega > m. This check is crucial.
        if m_param >= A_param * omega_param:
            return 1e9 # Return a large number if parameters are invalid

        # Calculate the common terms based on the current 'A_param' guess
        sqrt_term = np.sqrt(1 - (m_param**2 / (A_param**2 * omega_param**2)))
        arccos_term = np.arccos(-m_param / (A_param * omega_param))

        # Left-hand side of the master equation
        LHS = 2 * A_param * sqrt_term

        # Right-hand side of the master equation
        RHS = (m_param / omega_param) * (2 * np.pi * N_param - 2 * arccos_term)

        return LHS - RHS

    # --- 3. Find the Solution Numerically ---
    # Convert known frequency 'f' to angular frequency 'omega'
    omega = 2 * np.pi * f

    # For the solver to work, we need a reasonable initial guess for 'A'.
    # We can calculate one from our older, simpler formula: N = 2A/(mT) + 0.5
    # Solved for A: A = m*T*(N-0.5)/2 = m*(N-0.5)/(2*f)
    A_guess = (m * (N - 0.5)) / (2 * f)

    # Use fsolve to find the 'A' that makes our error_function zero.
    # The first argument to fsolve is the initial guess for the variable we are solving for.
    try:
        A_solution, = fsolve(error_function, A_guess, args=(m, omega, N))
    except Exception as e:
        print(f"An error occurred during solving: {e}")
        print("This may be because no physical solution exists for the given parameters.")
        return None


    # --- 4. Print the Results ---
    print("--- Solving for Amplitude for a Given N and Frequency ---")
    print(f"Parameters: m={m}, f={f:.6f} Hz, Target Cycle N={N}")
    print(f"Initial Guess for Amplitude (from simple model): A = {A_guess:.24f}")
    print("-" * 60)
    print(f"Precise Amplitude Solution (A): {A_solution:.24f}")

    return A_solution

# --- Run the Solver ---
if __name__ == '__main__':
    precise_amplitude = find_amplitude_for_N()
# Out:
# --- Solving for Amplitude for a Given N and Frequency ---
# Parameters: m=1.0, f=1235.590000 Hz, Target Cycle N=3030
# Initial Guess for Amplitude (from simple model): A = 1.225932550441489521375615
# ------------------------------------------------------------
# Precise Amplitude Solution (A): 1.225932543674509211939494

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_and_process_signal():
    """
    Generates a composite signal, splits it at its true turning points,
    plots the original result, and then creates a second plot with the
    segments rearranged cyclically.
    """
    # --- 1. Signal Parameters ---
    amplitude = 2.0
    frequency = 0.619885
    wave_speed = 1.0
    num_cycles = 3
    slope_degrees = 45.0

    # --- 2. Calculate Spatial & Signal Properties ---
    if frequency <= 0:
        raise ValueError("Frequency must be a positive number.")
    wavelength = wave_speed / frequency
    k = 2 * np.pi / wavelength  # Wave number
    slope_gradient = np.tan(np.deg2rad(slope_degrees)) # Slope 'm'

    print(f"--- Wave Properties ---")
    print(f"Calculated Wavelength: {wavelength:.4f}")
    print(f"Wave Number (k): {k:.4f}")
    print(f"Slope (m): {slope_gradient:.4f}\n")

    # --- 3. Generate the Signal Data ---
    x_max = num_cycles * wavelength
    num_points = int(num_cycles * 500)
    x_values = np.linspace(0, x_max, num_points)
    y_sine = amplitude * np.sin(k * x_values)
    y_linear = slope_gradient * x_values
    y_values = y_sine + y_linear

    # --- 4. Split Signal using Calculus (Derivative Method) ---
    cos_val = -slope_gradient / (amplitude * k)

    split_x_arrays = []
    split_y_arrays = []
    split_x_locations = []

    if abs(cos_val) > 1:
        print("No turning points exist. The linear slope is too steep.")
        split_x_arrays = [x_values]
        split_y_arrays = [y_values]
    else:
        principal_angle = np.arccos(cos_val)
        n = 0
        while True:
            x_loc1 = (2 * n * np.pi + principal_angle) / k
            x_loc2 = (2 * (n + 1) * np.pi - principal_angle) / k
            stop_adding = True
            if x_loc1 < x_max:
                split_x_locations.append(x_loc1)
                stop_adding = False
            if x_loc2 < x_max:
                split_x_locations.append(x_loc2)
                stop_adding = False
            if stop_adding: break
            n += 1
        
        split_x_locations.sort()
        split_indices_raw = np.searchsorted(x_values, split_x_locations)
        split_indices = np.concatenate(([0], split_indices_raw, [len(x_values) - 1]))

        for i in range(len(split_indices) - 1):
            start_index = split_indices[i]
            end_index = split_indices[i+1] + 1
            if i == len(split_indices) - 2: end_index = split_indices[i+1]
            split_x_arrays.append(x_values[start_index:end_index])
            split_y_arrays.append(y_values[start_index:end_index])

    print(f"--- Splitting Signal by Derivative ---")
    print(f"cos(kx) solved for: {cos_val:.4f}")
    print(f"Calculated {len(split_x_locations)} split points (extrema).")
    print(f"Splitting into {len(split_x_arrays)} segments.\n")

    # --- 5. Print the Original Split Vectors ---
    for i, (x_seg, y_seg) in enumerate(zip(split_x_arrays, split_y_arrays)):
        print(f"--- Original Vector for Segment {i+1} ---")
        print(f"Segment contains {len(x_seg)} points. X starts at {x_seg[0]:.2f}, Y starts at {y_seg[0]:.2f}")

    # --- 6. Plot the Original Results ---
    fig1, ax1 = plt.subplots(figsize=(15, 8))
    for i in range(len(split_x_arrays)):
        ax1.plot(split_x_arrays[i], split_y_arrays[i],
                 label=f'Segment {i+1}', linewidth=2.5)
    ax1.vlines(split_x_locations, ymin=y_values.min(), ymax=y_values.max(),
               colors='red', linestyles=':', label='True Extrema (y\'=0)')
    ax1.set_title(f'Original Composite Signal (Split by Extrema)', fontsize=16)
    ax1.set_xlabel('X-axis (Distance)', fontsize=12)
    ax1.set_ylabel('Y-axis (Signal Value)', fontsize=12)
    ax1.legend(title='Signal Segments')
    fig1.tight_layout()
    plt.show()

    # --- 7. NEW: Cyclical Re-arrangement and Plotting ---
    print("\n--- Performing Cyclical Re-arrangement ---")
    N_cycles_rearrange = 2  # The number of groups to cycle through.
                           # Since a full wave cycle has 2 segments (up/down), N=2 is natural.

    # Create a list of lists to hold the grouped segments.
    # Each item will be a list of (x_array, y_array) tuples.
    rearranged_groups = [[] for _ in range(N_cycles_rearrange)]

    for i, (x_seg, y_seg) in enumerate(zip(split_x_arrays, split_y_arrays)):
        # Determine which group this segment belongs to
        group_index = i % N_cycles_rearrange
        
        # Reset the x-axis for this segment to start at 0
        x_reset = x_seg - x_seg[0]
        
        # Add the (reset_x, y) pair to the correct group
        rearranged_groups[group_index].append((x_reset, y_seg))

    print(f"Segments have been rearranged into {N_cycles_rearrange} groups.\n")

    # --- 8. NEW: Plot the Rearranged Data ---
    fig2, ax2 = plt.subplots(figsize=(15, 8))
    
    # Use a color map to give each group a distinct color
    colors = plt.cm.viridis(np.linspace(0, 1, N_cycles_rearrange))

    for i, group in enumerate(rearranged_groups):
        print(f"--- Group {i+1} ---")
        # Use varying alpha (transparency) to see overlapping segments
        alpha_values = np.linspace(1.0, 0.3, len(group))
        for j, (x_reset, y_seg) in enumerate(group):
            print(f"  Contains original segment {i + j*N_cycles_rearrange + 1}")
            ax2.plot(x_reset, y_seg, 
                     color=colors[i], 
                     alpha=alpha_values[j], 
                     linewidth=2, 
                     label=f'Group {i+1}, Cycle {j+1}')

    ax2.set_title(f'Segments Overlaid by Cyclical Grouping (N={N_cycles_rearrange})', fontsize=16)
    ax2.set_xlabel('X-axis (Relative Distance from Start of Segment)', fontsize=12)
    ax2.set_ylabel('Y-axis (Signal Value)', fontsize=12)
    # A full legend can be crowded, so we create a custom one for groups.
    from matplotlib.lines import Line2D
    custom_lines = [Line2D([0], [0], color=colors[i], lw=4) for i in range(N_cycles_rearrange)]
    ax2.legend(custom_lines, [f'Group {i+1}' for i in range(N_cycles_rearrange)], title="Segment Groups")
    fig2.tight_layout()
    plt.show()


if __name__ == '__main__':
    generate_and_process_signal()
# Out:
# --- Wave Properties ---
# Calculated Wavelength: 1.6132
# Wave Number (k): 3.8949
# Slope (m): 1.0000
#
# --- Splitting Signal by Derivative ---
# cos(kx) solved for: -0.1284
# Calculated 6 split points (extrema).
# Splitting into 7 segments.
#
# --- Original Vector for Segment 1 ---
# Segment contains 137 points. X starts at 0.00, Y starts at 0.00
# --- Original Vector for Segment 2 ---
# Segment contains 230 points. X starts at 0.44, Y starts at 2.42
# --- Original Vector for Segment 3 ---
# Segment contains 271 points. X starts at 1.18, Y starts at -0.81
# --- Original Vector for Segment 4 ---
# Segment contains 231 points. X starts at 2.05, Y starts at 4.03
# --- Original Vector for Segment 5 ---
# Segment contains 271 points. X starts at 2.79, Y starts at 0.81
# --- Original Vector for Segment 6 ---
# Segment contains 230 points. X starts at 3.66, Y starts at 5.65
# --- Original Vector for Segment 7 ---
# Segment contains 135 points. X starts at 4.40, Y starts at 2.42
# --- Performing Cyclical Re-arrangement ---
# Segments have been rearranged into 2 groups.
#
# --- Group 1 ---
#   Contains original segment 1
#   Contains original segment 3
#   Contains original segment 5
#   Contains original segment 7
# --- Group 2 ---
#   Contains original segment 2
#   Contains original segment 4
#   Contains original segment 6

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_and_process_signal():
    """
    Generates a composite signal, splits it at its true turning points,
    plots the original result, and then creates a second plot with
    segments appended based on a cycle-skip value N.
    """
    # --- 1. Signal Parameters ---
    amplitude = 1.225932543674509211939494
    frequency = 1.235590e+3
    wave_speed = 1.0
    num_cycles = 3030 * 3
    slope_degrees = 45.0

    # --- 2. Calculate Spatial & Signal Properties ---
    if frequency <= 0:
        raise ValueError("Frequency must be a positive number.")
    wavelength = wave_speed / frequency
    k = 2 * np.pi / wavelength
    slope_gradient = np.tan(np.deg2rad(slope_degrees))

    print(f"--- Wave Properties ---")
    print(f"Calculated Wavelength: {wavelength:.4f}")
    print(f"Wave Number (k): {k:.4f}")
    print(f"Slope (m): {slope_gradient:.4f}\n")

    # --- 3. Generate the Signal Data ---
    x_max = num_cycles * wavelength
    num_points = int(num_cycles * 500)
    x_values = np.linspace(0, x_max, num_points)
    y_sine = amplitude * np.sin(k * x_values)
    y_linear = slope_gradient * x_values
    y_values = y_sine + y_linear

    # --- 4. Split Signal using Calculus (Derivative Method) ---
    cos_val = -slope_gradient / (amplitude * k)

    split_y_arrays = []
    split_x_locations = []

    if abs(cos_val) > 1:
        print("No turning points exist. The linear slope is too steep.")
        split_y_arrays = [y_values]
    else:
        principal_angle = np.arccos(cos_val)
        n = 0
        while True:
            x_loc1 = (2 * n * np.pi + principal_angle) / k
            x_loc2 = (2 * (n + 1) * np.pi - principal_angle) / k
            stop_adding = True
            if x_loc1 < x_max:
                split_x_locations.append(x_loc1)
                stop_adding = False
            if x_loc2 < x_max:
                split_x_locations.append(x_loc2)
                stop_adding = False
            if stop_adding: break
            n += 1
        
        split_x_locations.sort()
        split_indices_raw = np.searchsorted(x_values, split_x_locations)
        split_indices = np.concatenate(([0], split_indices_raw, [len(x_values) - 1]))

        for i in range(len(split_indices) - 1):
            start_index = split_indices[i]
            end_index = split_indices[i+1]
            split_y_arrays.append(y_values[start_index:end_index])
    
    print(f"--- Splitting Signal by Derivative ---")
    print(f"cos(kx) solved for: {cos_val:.4f}")
    print(f"Calculated {len(split_x_locations)} split points (extrema).")
    print(f"Splitting into {len(split_y_arrays)} segments.\n")

    # --- 5. Plot the Original Results (UNCHANGED) ---
    fig1, ax1 = plt.subplots(figsize=(15, 8))
    split_x_arrays_for_plot = []
    for i in range(len(split_indices) - 1):
        start_index = split_indices[i]
        end_index = split_indices[i+1]
        split_x_arrays_for_plot.append(x_values[start_index:end_index])

    for i in range(len(split_x_arrays_for_plot)):
        ax1.plot(split_x_arrays_for_plot[i], split_y_arrays[i],
                 label=f'Segment {i+1}', linewidth=2.5)
    # ax1.vlines(split_x_locations, ymin=y_values.min(), ymax=y_values.max(),
            #    colors='red', linestyles=':', label='True Extrema (y\'=0)')
    ax1.set_title(f'Original Composite Signal (Split by Extrema)', fontsize=16)
    ax1.set_xlabel('X-axis (Distance)', fontsize=12)
    ax1.set_ylabel('Y-axis (Signal Value)', fontsize=12)
    # ax1.legend(title='Signal Segments')
    fig1.tight_layout()
    plt.show()

    # --- 6. NEW: Appending Segments Based on Cycle Skip N ---
    print("\n--- Performing Cyclical Segment Appending with new logic ---")
    N_cycles_skip_up = 3030
    N_cycles_skip_down = 3030- 1
    
    num_up_groups = N_cycles_skip_up
    num_down_groups = N_cycles_skip_down
    total_groups = num_up_groups + num_down_groups
    
    grouped_y_segments = [[] for _ in range(total_groups)]
    grouped_indices = [[] for _ in range(total_groups)]

    for i, y_seg in enumerate(split_y_arrays):
        if (i + 1) % 2 != 0: 
            up_segment_index = i // 2
            group_index = up_segment_index % num_up_groups
            segment_to_add = y_seg
        else: 
            down_segment_index = (i - 1) // 2
            group_index = (down_segment_index % num_down_groups) + num_up_groups
            segment_to_add = y_seg[::-1]
            
        grouped_y_segments[group_index].append(segment_to_add)
        grouped_indices[group_index].append(i + 1)

    final_merged_y_arrays = []
    for group in grouped_y_segments:
        if group:
            final_merged_y_arrays.append(np.concatenate(group))

    print(f"Segments merged with different logic for up/down segments.\n")

    # --- 7. NEW: Print and Plot the Merged Data ---
    fig2, ax2 = plt.subplots(figsize=(15, 8))
    colors = plt.cm.turbo(np.linspace(0, 1, len(final_merged_y_arrays)))

    for i, merged_y in enumerate(final_merged_y_arrays):
        x_merged = np.arange(len(merged_y))
        original_segs = grouped_indices[i]
        
        print(f"--- Merged Array {i+1} ---")
        print(f"  Created by appending original segments: {original_segs}")
        print(f"  Total length: {len(merged_y)} points.\n")
        
        legend_label = f'Segs: {original_segs}'
        ax2.plot(x_merged, merged_y, color=colors[i], label=legend_label)
        
    # --- ADDITION: Calculate and plot the overall average ---
    # To average arrays of different lengths, we must first interpolate them
    # to a common length (the length of the longest array).
    if final_merged_y_arrays:
        max_len = max(len(arr) for arr in final_merged_y_arrays)
        
        interpolated_arrays = []
        for merged_y in final_merged_y_arrays:
            original_x = np.linspace(0, 1, len(merged_y))
            new_x = np.linspace(0, 1, max_len)
            interpolated_y = np.interp(new_x, original_x, merged_y)
            interpolated_arrays.append(interpolated_y)
            
        # Calculate the element-wise average of all interpolated arrays
        average_y = np.mean(interpolated_arrays, axis=0)
        average_x = np.arange(len(average_y))
        
        # Plot the average line
        ax2.plot(average_x, average_y, color='black', linestyle='--', linewidth=3, label='Overall Average', zorder=10)
    
    ax2.set_title(f'Segments Appended with Custom Logic (Reversed)', fontsize=16)
    ax2.set_xlabel('Sample Index (Sequential Points)', fontsize=12)
    ax2.set_ylabel('Y-axis (Signal Value)', fontsize=12)
    # ax2.legend(title="Merged Groups", fontsize='small')
    ax2.grid(True)
    fig2.tight_layout()
    plt.show()


if __name__ == '__main__':
    generate_and_process_signal()
# Out:
# --- Wave Properties ---
# Calculated Wavelength: 0.0008
# Wave Number (k): 7763.4409
# Slope (m): 1.0000
#
# --- Splitting Signal by Derivative ---
# cos(kx) solved for: -0.0001
# Calculated 18180 split points (extrema).
# Splitting into 18181 segments.
# --- Performing Cyclical Segment Appending with new logic ---
# Segments merged with different logic for up/down segments.
#
# --- Merged Array 1 ---
#   Created by appending original segments: [1, 6061, 12121, 18181]
#   Total length: 751 points.
#
# --- Merged Array 2 ---
#   Created by appending original segments: [3, 6063, 12123]
#   Total length: 751 points.
#
# --- Merged Array 3 ---
#   Created by appending original segments: [5, 6065, 12125]
#   Total length: 751 points.
#
# --- Merged Array 4 ---
#   Created by appending original segments: [7, 6067, 12127]
#   Total length: 751 points.
#
# --- Merged Array 5 ---
#   Created by appending original segments: [9, 6069, 12129]
#   Total length: 751 points.
#
# --- Merged Array 6 ---
#   Created by appending original segments: [11, 6071, 12131]
#   Total length: 751 points.
#
# --- Merged Array 7 ---
#   Created by appending original segments: [13, 6073, 12133]
#   Total length: 751 points.
#
# --- Merged Array 8 ---
#   Created by appending original segments: [15, 6075, 12135]
#   Total length: 751 points.
#
# --- Merged Array 9 ---
#   Created by appending original segments: [17, 6077, 12137]
#   Total length: 751 points.
#
# --- Merged Array 10 ---
#   Created by appending original segments: [19, 6079, 12139]
#   Total length: 751 points.
#
# --- Merged Array 11 ---
#   Created by appending original segments: [21, 6081, 12141]
#   Total length: 751 points.
#
# --- Merged Array 12 ---
#   Created by appending original segments: [23, 6083, 12143]
#   Total length: 751 points.
#
# --- Merged Array 13 ---
#   Created by appending original segments: [25, 6085, 12145]
#   Total length: 751 points.
#
# --- Merged Array 14 ---
#   Created by appending original segments: [27, 6087, 12147]
#   Total length: 751 points.
#
# --- Merged Array 15 ---
#   Created by appending original segments: [29, 6089, 12149]
#   Total length: 751 points.
#
# --- Merged Array 16 ---
#   Created by appending original segments: [31, 6091, 12151]
#   Total length: 751 points.
#
# --- Merged Array 17 ---
#   Created by appending original segments: [33, 6093, 12153]
#   Total length: 751 points.
#
# --- Merged Array 18 ---
#   Created by appending original segments: [35, 6095, 12155]
#   Total length: 751 points.
#
# --- Merged Array 19 ---
#   Created by appending original segments: [37, 6097, 12157]
#   Total length: 751 points.
#
# --- Merged Array 20 ---
#   Created by appending original segments: [39, 6099, 12159]
#   Total length: 751 points.
#
# --- Merged Array 21 ---
#   Created by appending original segments: [41, 6101, 12161]
#   Total length: 751 points.
#
# --- Merged Array 22 ---
#   Created by appending original segments: [43, 6103, 12163]
#   Total length: 751 points.
#
# --- Merged Array 23 ---
#   Created by appending original segments: [45, 6105, 12165]
#   Total length: 751 points.
#
# --- Merged Array 24 ---
#   Created by appending original segments: [47, 6107, 12167]
#   Total length: 751 points.
#
# --- Merged Array 25 ---
#   Created by appending original segments: [49, 6109, 12169]
#   Total length: 751 points.
#
# --- Merged Array 26 ---
#   Created by appending original segments: [51, 6111, 12171]
#   Total length: 751 points.
#
# --- Merged Array 27 ---
#   Created by appending original segments: [53, 6113, 12173]
#   Total length: 751 points.
#
# --- Merged Array 28 ---
#   Created by appending original segments: [55, 6115, 12175]
#   Total length: 751 points.
#
# --- Merged Array 29 ---
#   Created by appending original segments: [57, 6117, 12177]
#   Total length: 751 points.
#
# --- Merged Array 30 ---
#   Created by appending original segments: [59, 6119, 12179]
#   Total length: 751 points.
#
# --- Merged Array 31 ---
#   Created by appending original segments: [61, 6121, 12181]
#   Total length: 751 points.
#
# --- Merged Array 32 ---
#   Created by appending original segments: [63, 6123, 12183]
#   Total length: 751 points.
#
# --- Merged Array 33 ---
#   Created by appending original segments: [65, 6125, 12185]
#   Total length: 751 points.
#
# --- Merged Array 34 ---
#   Created by appending original segments: [67, 6127, 12187]
#   Total length: 751 points.
#
# --- Merged Array 35 ---
#   Created by appending original segments: [69, 6129, 12189]
#   Total length: 751 points.
#
# --- Merged Array 36 ---
#   Created by appending original segments: [71, 6131, 12191]
#   Total length: 751 points.
#
# --- Merged Array 37 ---
#   Created by appending original segments: [73, 6133, 12193]
#   Total length: 751 points.
#
# --- Merged Array 38 ---
#   Created by appending original segments: [75, 6135, 12195]
#   Total length: 751 points.
#
# --- Merged Array 39 ---
#   Created by appending original segments: [77, 6137, 12197]
#   Total length: 751 points.
#
# --- Merged Array 40 ---
#   Created by appending original segments: [79, 6139, 12199]
#   Total length: 751 points.
#
# --- Merged Array 41 ---
#   Created by appending original segments: [81, 6141, 12201]
#   Total length: 751 points.
#
# --- Merged Array 42 ---
#   Created by appending original segments: [83, 6143, 12203]
#   Total length: 751 points.
#
# --- Merged Array 43 ---
#   Created by appending original segments: [85, 6145, 12205]
#   Total length: 751 points.
#
# --- Merged Array 44 ---
#   Created by appending original segments: [87, 6147, 12207]
#   Total length: 751 points.
#
# --- Merged Array 45 ---
#   Created by appending original segments: [89, 6149, 12209]
#   Total length: 751 points.
#
# --- Merged Array 46 ---
#   Created by appending original segments: [91, 6151, 12211]
#   Total length: 751 points.
#
# --- Merged Array 47 ---
#   Created by appending original segments: [93, 6153, 12213]
#   Total length: 751 points.
#
# --- Merged Array 48 ---
#   Created by appending original segments: [95, 6155, 12215]
#   Total length: 751 points.
#
# --- Merged Array 49 ---
#   Created by appending original segments: [97, 6157, 12217]
#   Total length: 751 points.
#
# --- Merged Array 50 ---
#   Created by appending original segments: [99, 6159, 12219]
#   Total length: 751 points.
#
# --- Merged Array 51 ---
#   Created by appending original segments: [101, 6161, 12221]
#   Total length: 751 points.
#
# --- Merged Array 52 ---
#   Created by appending original segments: [103, 6163, 12223]
#   Total length: 751 points.
#
# --- Merged Array 53 ---
#   Created by appending original segments: [105, 6165, 12225]
#   Total length: 751 points.
#
# --- Merged Array 54 ---
#   Created by appending original segments: [107, 6167, 12227]
#   Total length: 751 points.
#
# --- Merged Array 55 ---
#   Created by appending original segments: [109, 6169, 12229]
#   Total length: 751 points.
#
# --- Merged Array 56 ---
#   Created by appending original segments: [111, 6171, 12231]
#   Total length: 751 points.
#
# --- Merged Array 57 ---
#   Created by appending original segments: [113, 6173, 12233]
#   Total length: 751 points.
#
# --- Merged Array 58 ---
#   Created by appending original segments: [115, 6175, 12235]
#   Total length: 751 points.
#
# --- Merged Array 59 ---
#   Created by appending original segments: [117, 6177, 12237]
#   Total length: 751 points.
#
# --- Merged Array 60 ---
#   Created by appending original segments: [119, 6179, 12239]
#   Total length: 751 points.
#
# --- Merged Array 61 ---
#   Created by appending original segments: [121, 6181, 12241]
#   Total length: 751 points.
#
# --- Merged Array 62 ---
#   Created by appending original segments: [123, 6183, 12243]
#   Total length: 751 points.
#
# --- Merged Array 63 ---
#   Created by appending original segments: [125, 6185, 12245]
#   Total length: 751 points.
#
# --- Merged Array 64 ---
#   Created by appending original segments: [127, 6187, 12247]
#   Total length: 751 points.
#
# --- Merged Array 65 ---
#   Created by appending original segments: [129, 6189, 12249]
#   Total length: 751 points.
#
# --- Merged Array 66 ---
#   Created by appending original segments: [131, 6191, 12251]
#   Total length: 751 points.
#
# --- Merged Array 67 ---
#   Created by appending original segments: [133, 6193, 12253]
#   Total length: 751 points.
#
# --- Merged Array 68 ---
#   Created by appending original segments: [135, 6195, 12255]
#   Total length: 751 points.
#
# --- Merged Array 69 ---
#   Created by appending original segments: [137, 6197, 12257]
#   Total length: 751 points.
#
# --- Merged Array 70 ---
#   Created by appending original segments: [139, 6199, 12259]
#   Total length: 751 points.
#
# --- Merged Array 71 ---
#   Created by appending original segments: [141, 6201, 12261]
#   Total length: 751 points.
#
# --- Merged Array 72 ---
#   Created by appending original segments: [143, 6203, 12263]
#   Total length: 751 points.
#
# --- Merged Array 73 ---
#   Created by appending original segments: [145, 6205, 12265]
#   Total length: 751 points.
#
# --- Merged Array 74 ---
#   Created by appending original segments: [147, 6207, 12267]
#   Total length: 751 points.
#
# --- Merged Array 75 ---
#   Created by appending original segments: [149, 6209, 12269]
#   Total length: 751 points.
#
# --- Merged Array 76 ---
#   Created by appending original segments: [151, 6211, 12271]
#   Total length: 751 points.
#
# --- Merged Array 77 ---
#   Created by appending original segments: [153, 6213, 12273]
#   Total length: 750 points.
#
# --- Merged Array 78 ---
#   Created by appending original segments: [155, 6215, 12275]
#   Total length: 750 points.
#
# --- Merged Array 79 ---
#   Created by appending original segments: [157, 6217, 12277]
#   Total length: 750 points.
#
# --- Merged Array 80 ---
#   Created by appending original segments: [159, 6219, 12279]
#   Total length: 750 points.
#
# --- Merged Array 81 ---
#   Created by appending original segments: [161, 6221, 12281]
#   Total length: 750 points.
#
# --- Merged Array 82 ---
#   Created by appending original segments: [163, 6223, 12283]
#   Total length: 750 points.
#
# --- Merged Array 83 ---
#   Created by appending original segments: [165, 6225, 12285]
#   Total length: 750 points.
#
# --- Merged Array 84 ---
#   Created by appending original segments: [167, 6227, 12287]
#   Total length: 750 points.
#
# --- Merged Array 85 ---
#   Created by appending original segments: [169, 6229, 12289]
#   Total length: 750 points.
#
# --- Merged Array 86 ---
#   Created by appending original segments: [171, 6231, 12291]
#   Total length: 750 points.
#
# --- Merged Array 87 ---
#   Created by appending original segments: [173, 6233, 12293]
#   Total length: 750 points.
#
# --- Merged Array 88 ---
#   Created by appending original segments: [175, 6235, 12295]
#   Total length: 750 points.
#
# --- Merged Array 89 ---
#   Created by appending original segments: [177, 6237, 12297]
#   Total length: 750 points.
#
# --- Merged Array 90 ---
#   Created by appending original segments: [179, 6239, 12299]
#   Total length: 750 points.
#
# --- Merged Array 91 ---
#   Created by appending original segments: [181, 6241, 12301]
#   Total length: 750 points.
#
# --- Merged Array 92 ---
#   Created by appending original segments: [183, 6243, 12303]
#   Total length: 750 points.
#
# --- Merged Array 93 ---
#   Created by appending original segments: [185, 6245, 12305]
#   Total length: 750 points.
#
# --- Merged Array 94 ---
#   Created by appending original segments: [187, 6247, 12307]
#   Total length: 750 points.
#
# --- Merged Array 95 ---
#   Created by appending original segments: [189, 6249, 12309]
#   Total length: 750 points.
#
# --- Merged Array 96 ---
#   Created by appending original segments: [191, 6251, 12311]
#   Total length: 750 points.
#
# --- Merged Array 97 ---
#   Created by appending original segments: [193, 6253, 12313]
#   Total length: 750 points.
#
# --- Merged Array 98 ---
#   Created by appending original segments: [195, 6255, 12315]
#   Total length: 750 points.
#
# --- Merged Array 99 ---
#   Created by appending original segments: [197, 6257, 12317]
#   Total length: 750 points.
#
# --- Merged Array 100 ---
#   Created by appending original segments: [199, 6259, 12319]
#   Total length: 750 points.
#
# --- Merged Array 101 ---
#   Created by appending original segments: [201, 6261, 12321]
#   Total length: 750 points.
#
# --- Merged Array 102 ---
#   Created by appending original segments: [203, 6263, 12323]
#   Total length: 750 points.
#
# --- Merged Array 103 ---
#   Created by appending original segments: [205, 6265, 12325]
#   Total length: 750 points.
#
# --- Merged Array 104 ---
#   Created by appending original segments: [207, 6267, 12327]
#   Total length: 750 points.
#
# --- Merged Array 105 ---
#   Created by appending original segments: [209, 6269, 12329]
#   Total length: 750 points.
#
# --- Merged Array 106 ---
#   Created by appending original segments: [211, 6271, 12331]
#   Total length: 750 points.
#
# --- Merged Array 107 ---
#   Created by appending original segments: [213, 6273, 12333]
#   Total length: 750 points.
#
# --- Merged Array 108 ---
#   Created by appending original segments: [215, 6275, 12335]
#   Total length: 750 points.
#
# --- Merged Array 109 ---
#   Created by appending original segments: [217, 6277, 12337]
#   Total length: 750 points.
#
# --- Merged Array 110 ---
#   Created by appending original segments: [219, 6279, 12339]
#   Total length: 750 points.
#
# --- Merged Array 111 ---
#   Created by appending original segments: [221, 6281, 12341]
#   Total length: 750 points.
#
# --- Merged Array 112 ---
#   Created by appending original segments: [223, 6283, 12343]
#   Total length: 750 points.
#
# --- Merged Array 113 ---
#   Created by appending original segments: [225, 6285, 12345]
#   Total length: 750 points.
#
# --- Merged Array 114 ---
#   Created by appending original segments: [227, 6287, 12347]
#   Total length: 750 points.
#
# --- Merged Array 115 ---
#   Created by appending original segments: [229, 6289, 12349]
#   Total length: 750 points.
#
# --- Merged Array 116 ---
#   Created by appending original segments: [231, 6291, 12351]
#   Total length: 750 points.
#
# --- Merged Array 117 ---
#   Created by appending original segments: [233, 6293, 12353]
#   Total length: 750 points.
#
# --- Merged Array 118 ---
#   Created by appending original segments: [235, 6295, 12355]
#   Total length: 750 points.
#
# --- Merged Array 119 ---
#   Created by appending original segments: [237, 6297, 12357]
#   Total length: 750 points.
#
# --- Merged Array 120 ---
#   Created by appending original segments: [239, 6299, 12359]
#   Total length: 750 points.
#
# --- Merged Array 121 ---
#   Created by appending original segments: [241, 6301, 12361]
#   Total length: 750 points.
#
# --- Merged Array 122 ---
#   Created by appending original segments: [243, 6303, 12363]
#   Total length: 750 points.
#
# --- Merged Array 123 ---
#   Created by appending original segments: [245, 6305, 12365]
#   Total length: 750 points.
#
# --- Merged Array 124 ---
#   Created by appending original segments: [247, 6307, 12367]
#   Total length: 750 points.
#
# --- Merged Array 125 ---
#   Created by appending original segments: [249, 6309, 12369]
#   Total length: 750 points.
#
# --- Merged Array 126 ---
#   Created by appending original segments: [251, 6311, 12371]
#   Total length: 750 points.
#
# --- Merged Array 127 ---
#   Created by appending original segments: [253, 6313, 12373]
#   Total length: 750 points.
#
# --- Merged Array 128 ---
#   Created by appending original segments: [255, 6315, 12375]
#   Total length: 750 points.
#
# --- Merged Array 129 ---
#   Created by appending original segments: [257, 6317, 12377]
#   Total length: 750 points.
#
# --- Merged Array 130 ---
#   Created by appending original segments: [259, 6319, 12379]
#   Total length: 750 points.
#
# --- Merged Array 131 ---
#   Created by appending original segments: [261, 6321, 12381]
#   Total length: 750 points.
#
# --- Merged Array 132 ---
#   Created by appending original segments: [263, 6323, 12383]
#   Total length: 750 points.
#
# --- Merged Array 133 ---
#   Created by appending original segments: [265, 6325, 12385]
#   Total length: 750 points.
#
# --- Merged Array 134 ---
#   Created by appending original segments: [267, 6327, 12387]
#   Total length: 750 points.
#
# --- Merged Array 135 ---
#   Created by appending original segments: [269, 6329, 12389]
#   Total length: 750 points.
#
# --- Merged Array 136 ---
#   Created by appending original segments: [271, 6331, 12391]
#   Total length: 750 points.
#
# --- Merged Array 137 ---
#   Created by appending original segments: [273, 6333, 12393]
#   Total length: 750 points.
#
# --- Merged Array 138 ---
#   Created by appending original segments: [275, 6335, 12395]
#   Total length: 750 points.
#
# --- Merged Array 139 ---
#   Created by appending original segments: [277, 6337, 12397]
#   Total length: 750 points.
#
# --- Merged Array 140 ---
#   Created by appending original segments: [279, 6339, 12399]
#   Total length: 750 points.
#
# --- Merged Array 141 ---
#   Created by appending original segments: [281, 6341, 12401]
#   Total length: 750 points.
#
# --- Merged Array 142 ---
#   Created by appending original segments: [283, 6343, 12403]
#   Total length: 750 points.
#
# --- Merged Array 143 ---
#   Created by appending original segments: [285, 6345, 12405]
#   Total length: 750 points.
#
# --- Merged Array 144 ---
#   Created by appending original segments: [287, 6347, 12407]
#   Total length: 750 points.
#
# --- Merged Array 145 ---
#   Created by appending original segments: [289, 6349, 12409]
#   Total length: 750 points.
#
# --- Merged Array 146 ---
#   Created by appending original segments: [291, 6351, 12411]
#   Total length: 750 points.
#
# --- Merged Array 147 ---
#   Created by appending original segments: [293, 6353, 12413]
#   Total length: 750 points.
#
# --- Merged Array 148 ---
#   Created by appending original segments: [295, 6355, 12415]
#   Total length: 750 points.
#
# --- Merged Array 149 ---
#   Created by appending original segments: [297, 6357, 12417]
#   Total length: 750 points.
#
# --- Merged Array 150 ---
#   Created by appending original segments: [299, 6359, 12419]
#   Total length: 750 points.
#
# --- Merged Array 151 ---
#   Created by appending original segments: [301, 6361, 12421]
#   Total length: 750 points.
#
# --- Merged Array 152 ---
#   Created by appending original segments: [303, 6363, 12423]
#   Total length: 750 points.
#
# --- Merged Array 153 ---
#   Created by appending original segments: [305, 6365, 12425]
#   Total length: 750 points.
#
# --- Merged Array 154 ---
#   Created by appending original segments: [307, 6367, 12427]
#   Total length: 750 points.
#
# --- Merged Array 155 ---
#   Created by appending original segments: [309, 6369, 12429]
#   Total length: 750 points.
#
# --- Merged Array 156 ---
#   Created by appending original segments: [311, 6371, 12431]
#   Total length: 750 points.
#
# --- Merged Array 157 ---
#   Created by appending original segments: [313, 6373, 12433]
#   Total length: 750 points.
#
# --- Merged Array 158 ---
#   Created by appending original segments: [315, 6375, 12435]
#   Total length: 750 points.
#
# --- Merged Array 159 ---
#   Created by appending original segments: [317, 6377, 12437]
#   Total length: 750 points.
#
# --- Merged Array 160 ---
#   Created by appending original segments: [319, 6379, 12439]
#   Total length: 750 points.
#
# --- Merged Array 161 ---
#   Created by appending original segments: [321, 6381, 12441]
#   Total length: 750 points.
#
# --- Merged Array 162 ---
#   Created by appending original segments: [323, 6383, 12443]
#   Total length: 750 points.
#
# --- Merged Array 163 ---
#   Created by appending original segments: [325, 6385, 12445]
#   Total length: 750 points.
#
# --- Merged Array 164 ---
#   Created by appending original segments: [327, 6387, 12447]
#   Total length: 750 points.
#
# --- Merged Array 165 ---
#   Created by appending original segments: [329, 6389, 12449]
#   Total length: 750 points.
#
# --- Merged Array 166 ---
#   Created by appending original segments: [331, 6391, 12451]
#   Total length: 750 points.
#
# --- Merged Array 167 ---
#   Created by appending original segments: [333, 6393, 12453]
#   Total length: 750 points.
#
# --- Merged Array 168 ---
#   Created by appending original segments: [335, 6395, 12455]
#   Total length: 750 points.
#
# --- Merged Array 169 ---
#   Created by appending original segments: [337, 6397, 12457]
#   Total length: 750 points.
#
# --- Merged Array 170 ---
#   Created by appending original segments: [339, 6399, 12459]
#   Total length: 750 points.
#
# --- Merged Array 171 ---
#   Created by appending original segments: [341, 6401, 12461]
#   Total length: 750 points.
#
# --- Merged Array 172 ---
#   Created by appending original segments: [343, 6403, 12463]
#   Total length: 750 points.
#
# --- Merged Array 173 ---
#   Created by appending original segments: [345, 6405, 12465]
#   Total length: 750 points.
#
# --- Merged Array 174 ---
#   Created by appending original segments: [347, 6407, 12467]
#   Total length: 750 points.
#
# --- Merged Array 175 ---
#   Created by appending original segments: [349, 6409, 12469]
#   Total length: 750 points.
#
# --- Merged Array 176 ---
#   Created by appending original segments: [351, 6411, 12471]
#   Total length: 750 points.
#
# --- Merged Array 177 ---
#   Created by appending original segments: [353, 6413, 12473]
#   Total length: 750 points.
#
# --- Merged Array 178 ---
#   Created by appending original segments: [355, 6415, 12475]
#   Total length: 750 points.
#
# --- Merged Array 179 ---
#   Created by appending original segments: [357, 6417, 12477]
#   Total length: 750 points.
#
# --- Merged Array 180 ---
#   Created by appending original segments: [359, 6419, 12479]
#   Total length: 750 points.
#
# --- Merged Array 181 ---
#   Created by appending original segments: [361, 6421, 12481]
#   Total length: 750 points.
#
# --- Merged Array 182 ---
#   Created by appending original segments: [363, 6423, 12483]
#   Total length: 750 points.
#
# --- Merged Array 183 ---
#   Created by appending original segments: [365, 6425, 12485]
#   Total length: 750 points.
#
# --- Merged Array 184 ---
#   Created by appending original segments: [367, 6427, 12487]
#   Total length: 750 points.
#
# --- Merged Array 185 ---
#   Created by appending original segments: [369, 6429, 12489]
#   Total length: 750 points.
#
# --- Merged Array 186 ---
#   Created by appending original segments: [371, 6431, 12491]
#   Total length: 750 points.
#
# --- Merged Array 187 ---
#   Created by appending original segments: [373, 6433, 12493]
#   Total length: 750 points.
#
# --- Merged Array 188 ---
#   Created by appending original segments: [375, 6435, 12495]
#   Total length: 750 points.
#
# --- Merged Array 189 ---
#   Created by appending original segments: [377, 6437, 12497]
#   Total length: 750 points.
#
# --- Merged Array 190 ---
#   Created by appending original segments: [379, 6439, 12499]
#   Total length: 750 points.
#
# --- Merged Array 191 ---
#   Created by appending original segments: [381, 6441, 12501]
#   Total length: 750 points.
#
# --- Merged Array 192 ---
#   Created by appending original segments: [383, 6443, 12503]
#   Total length: 750 points.
#
# --- Merged Array 193 ---
#   Created by appending original segments: [385, 6445, 12505]
#   Total length: 750 points.
#
# --- Merged Array 194 ---
#   Created by appending original segments: [387, 6447, 12507]
#   Total length: 750 points.
#
# --- Merged Array 195 ---
#   Created by appending original segments: [389, 6449, 12509]
#   Total length: 750 points.
#
# --- Merged Array 196 ---
#   Created by appending original segments: [391, 6451, 12511]
#   Total length: 750 points.
#
# --- Merged Array 197 ---
#   Created by appending original segments: [393, 6453, 12513]
#   Total length: 750 points.
#
# --- Merged Array 198 ---
#   Created by appending original segments: [395, 6455, 12515]
#   Total length: 750 points.
#
# --- Merged Array 199 ---
#   Created by appending original segments: [397, 6457, 12517]
#   Total length: 750 points.
#
# --- Merged Array 200 ---
#   Created by appending original segments: [399, 6459, 12519]
#   Total length: 750 points.
#
# --- Merged Array 201 ---
#   Created by appending original segments: [401, 6461, 12521]
#   Total length: 750 points.
#
# --- Merged Array 202 ---
#   Created by appending original segments: [403, 6463, 12523]
#   Total length: 750 points.
#
# --- Merged Array 203 ---
#   Created by appending original segments: [405, 6465, 12525]
#   Total length: 750 points.
#
# --- Merged Array 204 ---
#   Created by appending original segments: [407, 6467, 12527]
#   Total length: 750 points.
#
# --- Merged Array 205 ---
#   Created by appending original segments: [409, 6469, 12529]
#   Total length: 750 points.
#
# --- Merged Array 206 ---
#   Created by appending original segments: [411, 6471, 12531]
#   Total length: 750 points.
#
# --- Merged Array 207 ---
#   Created by appending original segments: [413, 6473, 12533]
#   Total length: 750 points.
#
# --- Merged Array 208 ---
#   Created by appending original segments: [415, 6475, 12535]
#   Total length: 750 points.
#
# --- Merged Array 209 ---
#   Created by appending original segments: [417, 6477, 12537]
#   Total length: 750 points.
#
# --- Merged Array 210 ---
#   Created by appending original segments: [419, 6479, 12539]
#   Total length: 750 points.
#
# --- Merged Array 211 ---
#   Created by appending original segments: [421, 6481, 12541]
#   Total length: 750 points.
#
# --- Merged Array 212 ---
#   Created by appending original segments: [423, 6483, 12543]
#   Total length: 750 points.
#
# --- Merged Array 213 ---
#   Created by appending original segments: [425, 6485, 12545]
#   Total length: 750 points.
#
# --- Merged Array 214 ---
#   Created by appending original segments: [427, 6487, 12547]
#   Total length: 750 points.
#
# --- Merged Array 215 ---
#   Created by appending original segments: [429, 6489, 12549]
#   Total length: 750 points.
#
# --- Merged Array 216 ---
#   Created by appending original segments: [431, 6491, 12551]
#   Total length: 750 points.
#
# --- Merged Array 217 ---
#   Created by appending original segments: [433, 6493, 12553]
#   Total length: 750 points.
#
# --- Merged Array 218 ---
#   Created by appending original segments: [435, 6495, 12555]
#   Total length: 750 points.
#
# --- Merged Array 219 ---
#   Created by appending original segments: [437, 6497, 12557]
#   Total length: 750 points.
#
# --- Merged Array 220 ---
#   Created by appending original segments: [439, 6499, 12559]
#   Total length: 750 points.
#
# --- Merged Array 221 ---
#   Created by appending original segments: [441, 6501, 12561]
#   Total length: 750 points.
#
# --- Merged Array 222 ---
#   Created by appending original segments: [443, 6503, 12563]
#   Total length: 750 points.
#
# --- Merged Array 223 ---
#   Created by appending original segments: [445, 6505, 12565]
#   Total length: 750 points.
#
# --- Merged Array 224 ---
#   Created by appending original segments: [447, 6507, 12567]
#   Total length: 750 points.
#
# --- Merged Array 225 ---
#   Created by appending original segments: [449, 6509, 12569]
#   Total length: 750 points.
#
# --- Merged Array 226 ---
#   Created by appending original segments: [451, 6511, 12571]
#   Total length: 750 points.
#
# --- Merged Array 227 ---
#   Created by appending original segments: [453, 6513, 12573]
#   Total length: 750 points.
#
# --- Merged Array 228 ---
#   Created by appending original segments: [455, 6515, 12575]
#   Total length: 750 points.
#
# --- Merged Array 229 ---
#   Created by appending original segments: [457, 6517, 12577]
#   Total length: 750 points.
#
# --- Merged Array 230 ---
#   Created by appending original segments: [459, 6519, 12579]
#   Total length: 750 points.
#
# --- Merged Array 231 ---
#   Created by appending original segments: [461, 6521, 12581]
#   Total length: 750 points.
#
# --- Merged Array 232 ---
#   Created by appending original segments: [463, 6523, 12583]
#   Total length: 750 points.
#
# --- Merged Array 233 ---
#   Created by appending original segments: [465, 6525, 12585]
#   Total length: 750 points.
#
# --- Merged Array 234 ---
#   Created by appending original segments: [467, 6527, 12587]
#   Total length: 750 points.
#
# --- Merged Array 235 ---
#   Created by appending original segments: [469, 6529, 12589]
#   Total length: 750 points.
#
# --- Merged Array 236 ---
#   Created by appending original segments: [471, 6531, 12591]
#   Total length: 750 points.
#
# --- Merged Array 237 ---
#   Created by appending original segments: [473, 6533, 12593]
#   Total length: 750 points.
#
# --- Merged Array 238 ---
#   Created by appending original segments: [475, 6535, 12595]
#   Total length: 750 points.
#
# --- Merged Array 239 ---
#   Created by appending original segments: [477, 6537, 12597]
#   Total length: 750 points.
#
# --- Merged Array 240 ---
#   Created by appending original segments: [479, 6539, 12599]
#   Total length: 750 points.
#
# --- Merged Array 241 ---
#   Created by appending original segments: [481, 6541, 12601]
#   Total length: 750 points.
#
# --- Merged Array 242 ---
#   Created by appending original segments: [483, 6543, 12603]
#   Total length: 750 points.
#
# --- Merged Array 243 ---
#   Created by appending original segments: [485, 6545, 12605]
#   Total length: 750 points.
#
# --- Merged Array 244 ---
#   Created by appending original segments: [487, 6547, 12607]
#   Total length: 750 points.
#
# --- Merged Array 245 ---
#   Created by appending original segments: [489, 6549, 12609]
#   Total length: 750 points.
#
# --- Merged Array 246 ---
#   Created by appending original segments: [491, 6551, 12611]
#   Total length: 750 points.
#
# --- Merged Array 247 ---
#   Created by appending original segments: [493, 6553, 12613]
#   Total length: 750 points.
#
# --- Merged Array 248 ---
#   Created by appending original segments: [495, 6555, 12615]
#   Total length: 750 points.
#
# --- Merged Array 249 ---
#   Created by appending original segments: [497, 6557, 12617]
#   Total length: 750 points.
#
# --- Merged Array 250 ---
#   Created by appending original segments: [499, 6559, 12619]
#   Total length: 750 points.
#
# --- Merged Array 251 ---
#   Created by appending original segments: [501, 6561, 12621]
#   Total length: 750 points.
#
# --- Merged Array 252 ---
#   Created by appending original segments: [503, 6563, 12623]
#   Total length: 750 points.
#
# --- Merged Array 253 ---
#   Created by appending original segments: [505, 6565, 12625]
#   Total length: 750 points.
#
# --- Merged Array 254 ---
#   Created by appending original segments: [507, 6567, 12627]
#   Total length: 750 points.
#
# --- Merged Array 255 ---
#   Created by appending original segments: [509, 6569, 12629]
#   Total length: 750 points.
#
# --- Merged Array 256 ---
#   Created by appending original segments: [511, 6571, 12631]
#   Total length: 750 points.
#
# --- Merged Array 257 ---
#   Created by appending original segments: [513, 6573, 12633]
#   Total length: 750 points.
#
# --- Merged Array 258 ---
#   Created by appending original segments: [515, 6575, 12635]
#   Total length: 750 points.
#
# --- Merged Array 259 ---
#   Created by appending original segments: [517, 6577, 12637]
#   Total length: 750 points.
#
# --- Merged Array 260 ---
#   Created by appending original segments: [519, 6579, 12639]
#   Total length: 750 points.
#
# --- Merged Array 261 ---
#   Created by appending original segments: [521, 6581, 12641]
#   Total length: 750 points.
#
# --- Merged Array 262 ---
#   Created by appending original segments: [523, 6583, 12643]
#   Total length: 750 points.
#
# --- Merged Array 263 ---
#   Created by appending original segments: [525, 6585, 12645]
#   Total length: 750 points.
#
# --- Merged Array 264 ---
#   Created by appending original segments: [527, 6587, 12647]
#   Total length: 750 points.
#
# --- Merged Array 265 ---
#   Created by appending original segments: [529, 6589, 12649]
#   Total length: 750 points.
#
# --- Merged Array 266 ---
#   Created by appending original segments: [531, 6591, 12651]
#   Total length: 750 points.
#
# --- Merged Array 267 ---
#   Created by appending original segments: [533, 6593, 12653]
#   Total length: 750 points.
#
# --- Merged Array 268 ---
#   Created by appending original segments: [535, 6595, 12655]
#   Total length: 750 points.
#
# --- Merged Array 269 ---
#   Created by appending original segments: [537, 6597, 12657]
#   Total length: 750 points.
#
# --- Merged Array 270 ---
#   Created by appending original segments: [539, 6599, 12659]
#   Total length: 750 points.
#
# --- Merged Array 271 ---
#   Created by appending original segments: [541, 6601, 12661]
#   Total length: 750 points.
#
# --- Merged Array 272 ---
#   Created by appending original segments: [543, 6603, 12663]
#   Total length: 750 points.
#
# --- Merged Array 273 ---
#   Created by appending original segments: [545, 6605, 12665]
#   Total length: 750 points.
#
# --- Merged Array 274 ---
#   Created by appending original segments: [547, 6607, 12667]
#   Total length: 750 points.
#
# --- Merged Array 275 ---
#   Created by appending original segments: [549, 6609, 12669]
#   Total length: 750 points.
#
# --- Merged Array 276 ---
#   Created by appending original segments: [551, 6611, 12671]
#   Total length: 750 points.
#
# --- Merged Array 277 ---
#   Created by appending original segments: [553, 6613, 12673]
#   Total length: 750 points.
#
# --- Merged Array 278 ---
#   Created by appending original segments: [555, 6615, 12675]
#   Total length: 750 points.
#
# --- Merged Array 279 ---
#   Created by appending original segments: [557, 6617, 12677]
#   Total length: 750 points.
#
# --- Merged Array 280 ---
#   Created by appending original segments: [559, 6619, 12679]
#   Total length: 750 points.
#
# --- Merged Array 281 ---
#   Created by appending original segments: [561, 6621, 12681]
#   Total length: 750 points.
#
# --- Merged Array 282 ---
#   Created by appending original segments: [563, 6623, 12683]
#   Total length: 750 points.
#
# --- Merged Array 283 ---
#   Created by appending original segments: [565, 6625, 12685]
#   Total length: 750 points.
#
# --- Merged Array 284 ---
#   Created by appending original segments: [567, 6627, 12687]
#   Total length: 750 points.
#
# --- Merged Array 285 ---
#   Created by appending original segments: [569, 6629, 12689]
#   Total length: 750 points.
#
# --- Merged Array 286 ---
#   Created by appending original segments: [571, 6631, 12691]
#   Total length: 750 points.
#
# --- Merged Array 287 ---
#   Created by appending original segments: [573, 6633, 12693]
#   Total length: 750 points.
#
# --- Merged Array 288 ---
#   Created by appending original segments: [575, 6635, 12695]
#   Total length: 750 points.
#
# --- Merged Array 289 ---
#   Created by appending original segments: [577, 6637, 12697]
#   Total length: 750 points.
#
# --- Merged Array 290 ---
#   Created by appending original segments: [579, 6639, 12699]
#   Total length: 750 points.
#
# --- Merged Array 291 ---
#   Created by appending original segments: [581, 6641, 12701]
#   Total length: 750 points.
#
# --- Merged Array 292 ---
#   Created by appending original segments: [583, 6643, 12703]
#   Total length: 750 points.
#
# --- Merged Array 293 ---
#   Created by appending original segments: [585, 6645, 12705]
#   Total length: 750 points.
#
# --- Merged Array 294 ---
#   Created by appending original segments: [587, 6647, 12707]
#   Total length: 750 points.
#
# --- Merged Array 295 ---
#   Created by appending original segments: [589, 6649, 12709]
#   Total length: 750 points.
#
# --- Merged Array 296 ---
#   Created by appending original segments: [591, 6651, 12711]
#   Total length: 750 points.
#
# --- Merged Array 297 ---
#   Created by appending original segments: [593, 6653, 12713]
#   Total length: 750 points.
#
# --- Merged Array 298 ---
#   Created by appending original segments: [595, 6655, 12715]
#   Total length: 750 points.
#
# --- Merged Array 299 ---
#   Created by appending original segments: [597, 6657, 12717]
#   Total length: 750 points.
#
# --- Merged Array 300 ---
#   Created by appending original segments: [599, 6659, 12719]
#   Total length: 750 points.
#
# --- Merged Array 301 ---
#   Created by appending original segments: [601, 6661, 12721]
#   Total length: 750 points.
#
# --- Merged Array 302 ---
#   Created by appending original segments: [603, 6663, 12723]
#   Total length: 750 points.
#
# --- Merged Array 303 ---
#   Created by appending original segments: [605, 6665, 12725]
#   Total length: 750 points.
#
# --- Merged Array 304 ---
#   Created by appending original segments: [607, 6667, 12727]
#   Total length: 750 points.
#
# --- Merged Array 305 ---
#   Created by appending original segments: [609, 6669, 12729]
#   Total length: 750 points.
#
# --- Merged Array 306 ---
#   Created by appending original segments: [611, 6671, 12731]
#   Total length: 750 points.
#
# --- Merged Array 307 ---
#   Created by appending original segments: [613, 6673, 12733]
#   Total length: 750 points.
#
# --- Merged Array 308 ---
#   Created by appending original segments: [615, 6675, 12735]
#   Total length: 750 points.
#
# --- Merged Array 309 ---
#   Created by appending original segments: [617, 6677, 12737]
#   Total length: 750 points.
#
# --- Merged Array 310 ---
#   Created by appending original segments: [619, 6679, 12739]
#   Total length: 750 points.
#
# --- Merged Array 311 ---
#   Created by appending original segments: [621, 6681, 12741]
#   Total length: 750 points.
#
# --- Merged Array 312 ---
#   Created by appending original segments: [623, 6683, 12743]
#   Total length: 750 points.
#
# --- Merged Array 313 ---
#   Created by appending original segments: [625, 6685, 12745]
#   Total length: 750 points.
#
# --- Merged Array 314 ---
#   Created by appending original segments: [627, 6687, 12747]
#   Total length: 750 points.
#
# --- Merged Array 315 ---
#   Created by appending original segments: [629, 6689, 12749]
#   Total length: 750 points.
#
# --- Merged Array 316 ---
#   Created by appending original segments: [631, 6691, 12751]
#   Total length: 750 points.
#
# --- Merged Array 317 ---
#   Created by appending original segments: [633, 6693, 12753]
#   Total length: 750 points.
#
# --- Merged Array 318 ---
#   Created by appending original segments: [635, 6695, 12755]
#   Total length: 750 points.
#
# --- Merged Array 319 ---
#   Created by appending original segments: [637, 6697, 12757]
#   Total length: 750 points.
#
# --- Merged Array 320 ---
#   Created by appending original segments: [639, 6699, 12759]
#   Total length: 750 points.
#
# --- Merged Array 321 ---
#   Created by appending original segments: [641, 6701, 12761]
#   Total length: 750 points.
#
# --- Merged Array 322 ---
#   Created by appending original segments: [643, 6703, 12763]
#   Total length: 750 points.
#
# --- Merged Array 323 ---
#   Created by appending original segments: [645, 6705, 12765]
#   Total length: 750 points.
#
# --- Merged Array 324 ---
#   Created by appending original segments: [647, 6707, 12767]
#   Total length: 750 points.
#
# --- Merged Array 325 ---
#   Created by appending original segments: [649, 6709, 12769]
#   Total length: 750 points.
#
# --- Merged Array 326 ---
#   Created by appending original segments: [651, 6711, 12771]
#   Total length: 750 points.
#
# --- Merged Array 327 ---
#   Created by appending original segments: [653, 6713, 12773]
#   Total length: 750 points.
#
# --- Merged Array 328 ---
#   Created by appending original segments: [655, 6715, 12775]
#   Total length: 750 points.
#
# --- Merged Array 329 ---
#   Created by appending original segments: [657, 6717, 12777]
#   Total length: 750 points.
#
# --- Merged Array 330 ---
#   Created by appending original segments: [659, 6719, 12779]
#   Total length: 750 points.
#
# --- Merged Array 331 ---
#   Created by appending original segments: [661, 6721, 12781]
#   Total length: 750 points.
#
# --- Merged Array 332 ---
#   Created by appending original segments: [663, 6723, 12783]
#   Total length: 750 points.
#
# --- Merged Array 333 ---
#   Created by appending original segments: [665, 6725, 12785]
#   Total length: 750 points.
#
# --- Merged Array 334 ---
#   Created by appending original segments: [667, 6727, 12787]
#   Total length: 750 points.
#
# --- Merged Array 335 ---
#   Created by appending original segments: [669, 6729, 12789]
#   Total length: 750 points.
#
# --- Merged Array 336 ---
#   Created by appending original segments: [671, 6731, 12791]
#   Total length: 750 points.
#
# --- Merged Array 337 ---
#   Created by appending original segments: [673, 6733, 12793]
#   Total length: 750 points.
#
# --- Merged Array 338 ---
#   Created by appending original segments: [675, 6735, 12795]
#   Total length: 750 points.
#
# --- Merged Array 339 ---
#   Created by appending original segments: [677, 6737, 12797]
#   Total length: 750 points.
#
# --- Merged Array 340 ---
#   Created by appending original segments: [679, 6739, 12799]
#   Total length: 750 points.
#
# --- Merged Array 341 ---
#   Created by appending original segments: [681, 6741, 12801]
#   Total length: 750 points.
#
# --- Merged Array 342 ---
#   Created by appending original segments: [683, 6743, 12803]
#   Total length: 750 points.
#
# --- Merged Array 343 ---
#   Created by appending original segments: [685, 6745, 12805]
#   Total length: 750 points.
#
# --- Merged Array 344 ---
#   Created by appending original segments: [687, 6747, 12807]
#   Total length: 750 points.
#
# --- Merged Array 345 ---
#   Created by appending original segments: [689, 6749, 12809]
#   Total length: 750 points.
#
# --- Merged Array 346 ---
#   Created by appending original segments: [691, 6751, 12811]
#   Total length: 750 points.
#
# --- Merged Array 347 ---
#   Created by appending original segments: [693, 6753, 12813]
#   Total length: 750 points.
#
# --- Merged Array 348 ---
#   Created by appending original segments: [695, 6755, 12815]
#   Total length: 750 points.
#
# --- Merged Array 349 ---
#   Created by appending original segments: [697, 6757, 12817]
#   Total length: 750 points.
#
# --- Merged Array 350 ---
#   Created by appending original segments: [699, 6759, 12819]
#   Total length: 750 points.
#
# --- Merged Array 351 ---
#   Created by appending original segments: [701, 6761, 12821]
#   Total length: 750 points.
#
# --- Merged Array 352 ---
#   Created by appending original segments: [703, 6763, 12823]
#   Total length: 750 points.
#
# --- Merged Array 353 ---
#   Created by appending original segments: [705, 6765, 12825]
#   Total length: 750 points.
#
# --- Merged Array 354 ---
#   Created by appending original segments: [707, 6767, 12827]
#   Total length: 750 points.
#
# --- Merged Array 355 ---
#   Created by appending original segments: [709, 6769, 12829]
#   Total length: 750 points.
#
# --- Merged Array 356 ---
#   Created by appending original segments: [711, 6771, 12831]
#   Total length: 750 points.
#
# --- Merged Array 357 ---
#   Created by appending original segments: [713, 6773, 12833]
#   Total length: 750 points.
#
# --- Merged Array 358 ---
#   Created by appending original segments: [715, 6775, 12835]
#   Total length: 750 points.
#
# --- Merged Array 359 ---
#   Created by appending original segments: [717, 6777, 12837]
#   Total length: 750 points.
#
# --- Merged Array 360 ---
#   Created by appending original segments: [719, 6779, 12839]
#   Total length: 750 points.
#
# --- Merged Array 361 ---
#   Created by appending original segments: [721, 6781, 12841]
#   Total length: 750 points.
#
# --- Merged Array 362 ---
#   Created by appending original segments: [723, 6783, 12843]
#   Total length: 750 points.
#
# --- Merged Array 363 ---
#   Created by appending original segments: [725, 6785, 12845]
#   Total length: 750 points.
#
# --- Merged Array 364 ---
#   Created by appending original segments: [727, 6787, 12847]
#   Total length: 750 points.
#
# --- Merged Array 365 ---
#   Created by appending original segments: [729, 6789, 12849]
#   Total length: 750 points.
#
# --- Merged Array 366 ---
#   Created by appending original segments: [731, 6791, 12851]
#   Total length: 750 points.
#
# --- Merged Array 367 ---
#   Created by appending original segments: [733, 6793, 12853]
#   Total length: 750 points.
#
# --- Merged Array 368 ---
#   Created by appending original segments: [735, 6795, 12855]
#   Total length: 750 points.
#
# --- Merged Array 369 ---
#   Created by appending original segments: [737, 6797, 12857]
#   Total length: 750 points.
#
# --- Merged Array 370 ---
#   Created by appending original segments: [739, 6799, 12859]
#   Total length: 750 points.
#
# --- Merged Array 371 ---
#   Created by appending original segments: [741, 6801, 12861]
#   Total length: 750 points.
#
# --- Merged Array 372 ---
#   Created by appending original segments: [743, 6803, 12863]
#   Total length: 750 points.
#
# --- Merged Array 373 ---
#   Created by appending original segments: [745, 6805, 12865]
#   Total length: 750 points.
#
# --- Merged Array 374 ---
#   Created by appending original segments: [747, 6807, 12867]
#   Total length: 750 points.
#
# --- Merged Array 375 ---
#   Created by appending original segments: [749, 6809, 12869]
#   Total length: 750 points.
#
# --- Merged Array 376 ---
#   Created by appending original segments: [751, 6811, 12871]
#   Total length: 750 points.
#
# --- Merged Array 377 ---
#   Created by appending original segments: [753, 6813, 12873]
#   Total length: 750 points.
#
# --- Merged Array 378 ---
#   Created by appending original segments: [755, 6815, 12875]
#   Total length: 750 points.
#
# --- Merged Array 379 ---
#   Created by appending original segments: [757, 6817, 12877]
#   Total length: 750 points.
#
# --- Merged Array 380 ---
#   Created by appending original segments: [759, 6819, 12879]
#   Total length: 750 points.
#
# --- Merged Array 381 ---
#   Created by appending original segments: [761, 6821, 12881]
#   Total length: 750 points.
#
# --- Merged Array 382 ---
#   Created by appending original segments: [763, 6823, 12883]
#   Total length: 750 points.
#
# --- Merged Array 383 ---
#   Created by appending original segments: [765, 6825, 12885]
#   Total length: 750 points.
#
# --- Merged Array 384 ---
#   Created by appending original segments: [767, 6827, 12887]
#   Total length: 750 points.
#
# --- Merged Array 385 ---
#   Created by appending original segments: [769, 6829, 12889]
#   Total length: 750 points.
#
# --- Merged Array 386 ---
#   Created by appending original segments: [771, 6831, 12891]
#   Total length: 750 points.
#
# --- Merged Array 387 ---
#   Created by appending original segments: [773, 6833, 12893]
#   Total length: 750 points.
#
# --- Merged Array 388 ---
#   Created by appending original segments: [775, 6835, 12895]
#   Total length: 750 points.
#
# --- Merged Array 389 ---
#   Created by appending original segments: [777, 6837, 12897]
#   Total length: 750 points.
#
# --- Merged Array 390 ---
#   Created by appending original segments: [779, 6839, 12899]
#   Total length: 750 points.
#
# --- Merged Array 391 ---
#   Created by appending original segments: [781, 6841, 12901]
#   Total length: 750 points.
#
# --- Merged Array 392 ---
#   Created by appending original segments: [783, 6843, 12903]
#   Total length: 750 points.
#
# --- Merged Array 393 ---
#   Created by appending original segments: [785, 6845, 12905]
#   Total length: 750 points.
#
# --- Merged Array 394 ---
#   Created by appending original segments: [787, 6847, 12907]
#   Total length: 750 points.
#
# --- Merged Array 395 ---
#   Created by appending original segments: [789, 6849, 12909]
#   Total length: 750 points.
#
# --- Merged Array 396 ---
#   Created by appending original segments: [791, 6851, 12911]
#   Total length: 750 points.
#
# --- Merged Array 397 ---
#   Created by appending original segments: [793, 6853, 12913]
#   Total length: 750 points.
#
# --- Merged Array 398 ---
#   Created by appending original segments: [795, 6855, 12915]
#   Total length: 750 points.
#
# --- Merged Array 399 ---
#   Created by appending original segments: [797, 6857, 12917]
#   Total length: 750 points.
#
# --- Merged Array 400 ---
#   Created by appending original segments: [799, 6859, 12919]
#   Total length: 750 points.
#
# --- Merged Array 401 ---
#   Created by appending original segments: [801, 6861, 12921]
#   Total length: 750 points.
#
# --- Merged Array 402 ---
#   Created by appending original segments: [803, 6863, 12923]
#   Total length: 750 points.
#
# --- Merged Array 403 ---
#   Created by appending original segments: [805, 6865, 12925]
#   Total length: 750 points.
#
# --- Merged Array 404 ---
#   Created by appending original segments: [807, 6867, 12927]
#   Total length: 750 points.
#
# --- Merged Array 405 ---
#   Created by appending original segments: [809, 6869, 12929]
#   Total length: 750 points.
#
# --- Merged Array 406 ---
#   Created by appending original segments: [811, 6871, 12931]
#   Total length: 750 points.
#
# --- Merged Array 407 ---
#   Created by appending original segments: [813, 6873, 12933]
#   Total length: 750 points.
#
# --- Merged Array 408 ---
#   Created by appending original segments: [815, 6875, 12935]
#   Total length: 750 points.
#
# --- Merged Array 409 ---
#   Created by appending original segments: [817, 6877, 12937]
#   Total length: 750 points.
#
# --- Merged Array 410 ---
#   Created by appending original segments: [819, 6879, 12939]
#   Total length: 750 points.
#
# --- Merged Array 411 ---
#   Created by appending original segments: [821, 6881, 12941]
#   Total length: 750 points.
#
# --- Merged Array 412 ---
#   Created by appending original segments: [823, 6883, 12943]
#   Total length: 750 points.
#
# --- Merged Array 413 ---
#   Created by appending original segments: [825, 6885, 12945]
#   Total length: 750 points.
#
# --- Merged Array 414 ---
#   Created by appending original segments: [827, 6887, 12947]
#   Total length: 750 points.
#
# --- Merged Array 415 ---
#   Created by appending original segments: [829, 6889, 12949]
#   Total length: 750 points.
#
# --- Merged Array 416 ---
# ...
#   Total length: 750 points.
#
# --- Merged Array 5925 ---
#   Created by appending original segments: [5790, 11848, 17906]
#   Total length: 750 points.
#
# --- Merged Array 5926 ---
#   Created by appending original segments: [5792, 11850, 17908]
#   Total length: 750 points.
#
# --- Merged Array 5927 ---
#   Created by appending original segments: [5794, 11852, 17910]
#   Total length: 750 points.
#
# --- Merged Array 5928 ---
#   Created by appending original segments: [5796, 11854, 17912]
#   Total length: 750 points.
#
# --- Merged Array 5929 ---
#   Created by appending original segments: [5798, 11856, 17914]
#   Total length: 750 points.
#
# --- Merged Array 5930 ---
#   Created by appending original segments: [5800, 11858, 17916]
#   Total length: 750 points.
#
# --- Merged Array 5931 ---
#   Created by appending original segments: [5802, 11860, 17918]
#   Total length: 750 points.
#
# --- Merged Array 5932 ---
#   Created by appending original segments: [5804, 11862, 17920]
#   Total length: 750 points.
#
# --- Merged Array 5933 ---
#   Created by appending original segments: [5806, 11864, 17922]
#   Total length: 750 points.
#
# --- Merged Array 5934 ---
#   Created by appending original segments: [5808, 11866, 17924]
#   Total length: 750 points.
#
# --- Merged Array 5935 ---
#   Created by appending original segments: [5810, 11868, 17926]
#   Total length: 750 points.
#
# --- Merged Array 5936 ---
#   Created by appending original segments: [5812, 11870, 17928]
#   Total length: 750 points.
#
# --- Merged Array 5937 ---
#   Created by appending original segments: [5814, 11872, 17930]
#   Total length: 750 points.
#
# --- Merged Array 5938 ---
#   Created by appending original segments: [5816, 11874, 17932]
#   Total length: 750 points.
#
# --- Merged Array 5939 ---
#   Created by appending original segments: [5818, 11876, 17934]
#   Total length: 750 points.
#
# --- Merged Array 5940 ---
#   Created by appending original segments: [5820, 11878, 17936]
#   Total length: 750 points.
#
# --- Merged Array 5941 ---
#   Created by appending original segments: [5822, 11880, 17938]
#   Total length: 750 points.
#
# --- Merged Array 5942 ---
#   Created by appending original segments: [5824, 11882, 17940]
#   Total length: 750 points.
#
# --- Merged Array 5943 ---
#   Created by appending original segments: [5826, 11884, 17942]
#   Total length: 750 points.
#
# --- Merged Array 5944 ---
#   Created by appending original segments: [5828, 11886, 17944]
#   Total length: 750 points.
#
# --- Merged Array 5945 ---
#   Created by appending original segments: [5830, 11888, 17946]
#   Total length: 750 points.
#
# --- Merged Array 5946 ---
#   Created by appending original segments: [5832, 11890, 17948]
#   Total length: 750 points.
#
# --- Merged Array 5947 ---
#   Created by appending original segments: [5834, 11892, 17950]
#   Total length: 750 points.
#
# --- Merged Array 5948 ---
#   Created by appending original segments: [5836, 11894, 17952]
#   Total length: 750 points.
#
# --- Merged Array 5949 ---
#   Created by appending original segments: [5838, 11896, 17954]
#   Total length: 750 points.
#
# --- Merged Array 5950 ---
#   Created by appending original segments: [5840, 11898, 17956]
#   Total length: 750 points.
#
# --- Merged Array 5951 ---
#   Created by appending original segments: [5842, 11900, 17958]
#   Total length: 750 points.
#
# --- Merged Array 5952 ---
#   Created by appending original segments: [5844, 11902, 17960]
#   Total length: 750 points.
#
# --- Merged Array 5953 ---
#   Created by appending original segments: [5846, 11904, 17962]
#   Total length: 750 points.
#
# --- Merged Array 5954 ---
#   Created by appending original segments: [5848, 11906, 17964]
#   Total length: 750 points.
#
# --- Merged Array 5955 ---
#   Created by appending original segments: [5850, 11908, 17966]
#   Total length: 750 points.
#
# --- Merged Array 5956 ---
#   Created by appending original segments: [5852, 11910, 17968]
#   Total length: 750 points.
#
# --- Merged Array 5957 ---
#   Created by appending original segments: [5854, 11912, 17970]
#   Total length: 750 points.
#
# --- Merged Array 5958 ---
#   Created by appending original segments: [5856, 11914, 17972]
#   Total length: 750 points.
#
# --- Merged Array 5959 ---
#   Created by appending original segments: [5858, 11916, 17974]
#   Total length: 750 points.
#
# --- Merged Array 5960 ---
#   Created by appending original segments: [5860, 11918, 17976]
#   Total length: 750 points.
#
# --- Merged Array 5961 ---
#   Created by appending original segments: [5862, 11920, 17978]
#   Total length: 750 points.
#
# --- Merged Array 5962 ---
#   Created by appending original segments: [5864, 11922, 17980]
#   Total length: 750 points.
#
# --- Merged Array 5963 ---
#   Created by appending original segments: [5866, 11924, 17982]
#   Total length: 750 points.
#
# --- Merged Array 5964 ---
#   Created by appending original segments: [5868, 11926, 17984]
#   Total length: 750 points.
#
# --- Merged Array 5965 ---
#   Created by appending original segments: [5870, 11928, 17986]
#   Total length: 750 points.
#
# --- Merged Array 5966 ---
#   Created by appending original segments: [5872, 11930, 17988]
#   Total length: 750 points.
#
# --- Merged Array 5967 ---
#   Created by appending original segments: [5874, 11932, 17990]
#   Total length: 750 points.
#
# --- Merged Array 5968 ---
#   Created by appending original segments: [5876, 11934, 17992]
#   Total length: 750 points.
#
# --- Merged Array 5969 ---
#   Created by appending original segments: [5878, 11936, 17994]
#   Total length: 750 points.
#
# --- Merged Array 5970 ---
#   Created by appending original segments: [5880, 11938, 17996]
#   Total length: 750 points.
#
# --- Merged Array 5971 ---
#   Created by appending original segments: [5882, 11940, 17998]
#   Total length: 750 points.
#
# --- Merged Array 5972 ---
#   Created by appending original segments: [5884, 11942, 18000]
#   Total length: 750 points.
#
# --- Merged Array 5973 ---
#   Created by appending original segments: [5886, 11944, 18002]
#   Total length: 750 points.
#
# --- Merged Array 5974 ---
#   Created by appending original segments: [5888, 11946, 18004]
#   Total length: 750 points.
#
# --- Merged Array 5975 ---
#   Created by appending original segments: [5890, 11948, 18006]
#   Total length: 750 points.
#
# --- Merged Array 5976 ---
#   Created by appending original segments: [5892, 11950, 18008]
#   Total length: 750 points.
#
# --- Merged Array 5977 ---
#   Created by appending original segments: [5894, 11952, 18010]
#   Total length: 750 points.
#
# --- Merged Array 5978 ---
#   Created by appending original segments: [5896, 11954, 18012]
#   Total length: 750 points.
#
# --- Merged Array 5979 ---
#   Created by appending original segments: [5898, 11956, 18014]
#   Total length: 750 points.
#
# --- Merged Array 5980 ---
#   Created by appending original segments: [5900, 11958, 18016]
#   Total length: 750 points.
#
# --- Merged Array 5981 ---
#   Created by appending original segments: [5902, 11960, 18018]
#   Total length: 750 points.
#
# --- Merged Array 5982 ---
#   Created by appending original segments: [5904, 11962, 18020]
#   Total length: 750 points.
#
# --- Merged Array 5983 ---
#   Created by appending original segments: [5906, 11964, 18022]
#   Total length: 750 points.
#
# --- Merged Array 5984 ---
#   Created by appending original segments: [5908, 11966, 18024]
#   Total length: 750 points.
#
# --- Merged Array 5985 ---
#   Created by appending original segments: [5910, 11968, 18026]
#   Total length: 750 points.
#
# --- Merged Array 5986 ---
#   Created by appending original segments: [5912, 11970, 18028]
#   Total length: 750 points.
#
# --- Merged Array 5987 ---
#   Created by appending original segments: [5914, 11972, 18030]
#   Total length: 749 points.
#
# --- Merged Array 5988 ---
#   Created by appending original segments: [5916, 11974, 18032]
#   Total length: 749 points.
#
# --- Merged Array 5989 ---
#   Created by appending original segments: [5918, 11976, 18034]
#   Total length: 749 points.
#
# --- Merged Array 5990 ---
#   Created by appending original segments: [5920, 11978, 18036]
#   Total length: 749 points.
#
# --- Merged Array 5991 ---
#   Created by appending original segments: [5922, 11980, 18038]
#   Total length: 749 points.
#
# --- Merged Array 5992 ---
#   Created by appending original segments: [5924, 11982, 18040]
#   Total length: 749 points.
#
# --- Merged Array 5993 ---
#   Created by appending original segments: [5926, 11984, 18042]
#   Total length: 749 points.
#
# --- Merged Array 5994 ---
#   Created by appending original segments: [5928, 11986, 18044]
#   Total length: 749 points.
#
# --- Merged Array 5995 ---
#   Created by appending original segments: [5930, 11988, 18046]
#   Total length: 749 points.
#
# --- Merged Array 5996 ---
#   Created by appending original segments: [5932, 11990, 18048]
#   Total length: 749 points.
#
# --- Merged Array 5997 ---
#   Created by appending original segments: [5934, 11992, 18050]
#   Total length: 749 points.
#
# --- Merged Array 5998 ---
#   Created by appending original segments: [5936, 11994, 18052]
#   Total length: 749 points.
#
# --- Merged Array 5999 ---
#   Created by appending original segments: [5938, 11996, 18054]
#   Total length: 749 points.
#
# --- Merged Array 6000 ---
#   Created by appending original segments: [5940, 11998, 18056]
#   Total length: 749 points.
#
# --- Merged Array 6001 ---
#   Created by appending original segments: [5942, 12000, 18058]
#   Total length: 749 points.
#
# --- Merged Array 6002 ---
#   Created by appending original segments: [5944, 12002, 18060]
#   Total length: 749 points.
#
# --- Merged Array 6003 ---
#   Created by appending original segments: [5946, 12004, 18062]
#   Total length: 749 points.
#
# --- Merged Array 6004 ---
#   Created by appending original segments: [5948, 12006, 18064]
#   Total length: 749 points.
#
# --- Merged Array 6005 ---
#   Created by appending original segments: [5950, 12008, 18066]
#   Total length: 749 points.
#
# --- Merged Array 6006 ---
#   Created by appending original segments: [5952, 12010, 18068]
#   Total length: 749 points.
#
# --- Merged Array 6007 ---
#   Created by appending original segments: [5954, 12012, 18070]
#   Total length: 749 points.
#
# --- Merged Array 6008 ---
#   Created by appending original segments: [5956, 12014, 18072]
#   Total length: 749 points.
#
# --- Merged Array 6009 ---
#   Created by appending original segments: [5958, 12016, 18074]
#   Total length: 749 points.
#
# --- Merged Array 6010 ---
#   Created by appending original segments: [5960, 12018, 18076]
#   Total length: 749 points.
#
# --- Merged Array 6011 ---
#   Created by appending original segments: [5962, 12020, 18078]
#   Total length: 749 points.
#
# --- Merged Array 6012 ---
#   Created by appending original segments: [5964, 12022, 18080]
#   Total length: 749 points.
#
# --- Merged Array 6013 ---
#   Created by appending original segments: [5966, 12024, 18082]
#   Total length: 749 points.
#
# --- Merged Array 6014 ---
#   Created by appending original segments: [5968, 12026, 18084]
#   Total length: 749 points.
#
# --- Merged Array 6015 ---
#   Created by appending original segments: [5970, 12028, 18086]
#   Total length: 749 points.
#
# --- Merged Array 6016 ---
#   Created by appending original segments: [5972, 12030, 18088]
#   Total length: 749 points.
#
# --- Merged Array 6017 ---
#   Created by appending original segments: [5974, 12032, 18090]
#   Total length: 749 points.
#
# --- Merged Array 6018 ---
#   Created by appending original segments: [5976, 12034, 18092]
#   Total length: 749 points.
#
# --- Merged Array 6019 ---
#   Created by appending original segments: [5978, 12036, 18094]
#   Total length: 749 points.
#
# --- Merged Array 6020 ---
#   Created by appending original segments: [5980, 12038, 18096]
#   Total length: 749 points.
#
# --- Merged Array 6021 ---
#   Created by appending original segments: [5982, 12040, 18098]
#   Total length: 749 points.
#
# --- Merged Array 6022 ---
#   Created by appending original segments: [5984, 12042, 18100]
#   Total length: 749 points.
#
# --- Merged Array 6023 ---
#   Created by appending original segments: [5986, 12044, 18102]
#   Total length: 749 points.
#
# --- Merged Array 6024 ---
#   Created by appending original segments: [5988, 12046, 18104]
#   Total length: 749 points.
#
# --- Merged Array 6025 ---
#   Created by appending original segments: [5990, 12048, 18106]
#   Total length: 749 points.
#
# --- Merged Array 6026 ---
#   Created by appending original segments: [5992, 12050, 18108]
#   Total length: 749 points.
#
# --- Merged Array 6027 ---
#   Created by appending original segments: [5994, 12052, 18110]
#   Total length: 749 points.
#
# --- Merged Array 6028 ---
#   Created by appending original segments: [5996, 12054, 18112]
#   Total length: 749 points.
#
# --- Merged Array 6029 ---
#   Created by appending original segments: [5998, 12056, 18114]
#   Total length: 749 points.
#
# --- Merged Array 6030 ---
#   Created by appending original segments: [6000, 12058, 18116]
#   Total length: 749 points.
#
# --- Merged Array 6031 ---
#   Created by appending original segments: [6002, 12060, 18118]
#   Total length: 749 points.
#
# --- Merged Array 6032 ---
#   Created by appending original segments: [6004, 12062, 18120]
#   Total length: 749 points.
#
# --- Merged Array 6033 ---
#   Created by appending original segments: [6006, 12064, 18122]
#   Total length: 749 points.
#
# --- Merged Array 6034 ---
#   Created by appending original segments: [6008, 12066, 18124]
#   Total length: 749 points.
#
# --- Merged Array 6035 ---
#   Created by appending original segments: [6010, 12068, 18126]
#   Total length: 749 points.
#
# --- Merged Array 6036 ---
#   Created by appending original segments: [6012, 12070, 18128]
#   Total length: 749 points.
#
# --- Merged Array 6037 ---
#   Created by appending original segments: [6014, 12072, 18130]
#   Total length: 749 points.
#
# --- Merged Array 6038 ---
#   Created by appending original segments: [6016, 12074, 18132]
#   Total length: 749 points.
#
# --- Merged Array 6039 ---
#   Created by appending original segments: [6018, 12076, 18134]
#   Total length: 749 points.
#
# --- Merged Array 6040 ---
#   Created by appending original segments: [6020, 12078, 18136]
#   Total length: 749 points.
#
# --- Merged Array 6041 ---
#   Created by appending original segments: [6022, 12080, 18138]
#   Total length: 749 points.
#
# --- Merged Array 6042 ---
#   Created by appending original segments: [6024, 12082, 18140]
#   Total length: 749 points.
#
# --- Merged Array 6043 ---
#   Created by appending original segments: [6026, 12084, 18142]
#   Total length: 749 points.
#
# --- Merged Array 6044 ---
#   Created by appending original segments: [6028, 12086, 18144]
#   Total length: 749 points.
#
# --- Merged Array 6045 ---
#   Created by appending original segments: [6030, 12088, 18146]
#   Total length: 749 points.
#
# --- Merged Array 6046 ---
#   Created by appending original segments: [6032, 12090, 18148]
#   Total length: 749 points.
#
# --- Merged Array 6047 ---
#   Created by appending original segments: [6034, 12092, 18150]
#   Total length: 749 points.
#
# --- Merged Array 6048 ---
#   Created by appending original segments: [6036, 12094, 18152]
#   Total length: 749 points.
#
# --- Merged Array 6049 ---
#   Created by appending original segments: [6038, 12096, 18154]
#   Total length: 749 points.
#
# --- Merged Array 6050 ---
#   Created by appending original segments: [6040, 12098, 18156]
#   Total length: 749 points.
#
# --- Merged Array 6051 ---
#   Created by appending original segments: [6042, 12100, 18158]
#   Total length: 749 points.
#
# --- Merged Array 6052 ---
#   Created by appending original segments: [6044, 12102, 18160]
#   Total length: 749 points.
#
# --- Merged Array 6053 ---
#   Created by appending original segments: [6046, 12104, 18162]
#   Total length: 749 points.
#
# --- Merged Array 6054 ---
#   Created by appending original segments: [6048, 12106, 18164]
#   Total length: 749 points.
#
# --- Merged Array 6055 ---
#   Created by appending original segments: [6050, 12108, 18166]
#   Total length: 749 points.
#
# --- Merged Array 6056 ---
#   Created by appending original segments: [6052, 12110, 18168]
#   Total length: 749 points.
#
# --- Merged Array 6057 ---
#   Created by appending original segments: [6054, 12112, 18170]
#   Total length: 749 points.
#
# --- Merged Array 6058 ---
#   Created by appending original segments: [6056, 12114, 18172]
#   Total length: 749 points.
#
# --- Merged Array 6059 ---
#   Created by appending original segments: [6058, 12116, 18174]
#   Total length: 749 points.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

def visualize_stitch_scenarios():
    """
    Visualizes the three states of the Topological Stitch:
    1. Stationary (Rest): Balanced Up/Down phases.
    2. Light Speed (Limit): The 'Down' phase vanishes.
    3. Instability (Broken): Slope exceeds amplitude, no stitch possible.
    """
    # Constants
    A = 2.0  # Amplitude
    k = 2 * np.pi # One cycle per unit
    t = np.linspace(0, 2.5, 1000) # Show 2.5 cycles
    
    # We will vary the Slope 'm' to create the scenarios
    # Derivative y' = Ak cos(kt) + m
    # Max downward slope of sine is -Ak.
    # Stitch breaks if m > Ak.
    
    max_sine_slope = A * k
    
    scenarios = [
        {"name": "1. Stationary / Massive Particle", "m": 0.0, "color": "green"},
        {"name": "2. Near Light Speed / Time Dilation", "m": 0.9 * max_sine_slope, "color": "blue"},
        {"name": "3. Instability / Broken Stitch", "m": 1.2 * max_sine_slope, "color": "red"}
    ]
    
    fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
    
    for i, scen in enumerate(scenarios):
        ax = axes[i]
        m = scen["m"]
        
        # Calculate Wave
        y = A * np.sin(k * t) + m * t
        print(y[:50])
        
        # Calculate Derivative for Coloring
        y_prime = A * k * np.cos(k * t) + m
        print(y_prime[:50])
        
        # Color Logic:
        # Positive Slope (Real) = Solid Color
        # Negative Slope (Branching) = Red/Dashed or Distinct
        
        # Create segments for LineCollection
        points = np.array([t, y]).T.reshape(-1, 1, 2)
        segments = np.concatenate([points[:-1], points[1:]], axis=1)
        
        # Determine colors based on derivative sign
        # 1 = Real (Up), -1 = Branching (Down)
        signs = np.sign(y_prime[:-1])
        # print(signs)
        
        # Custom color map for this segment
        # We'll construct a list of colors manually for clarity
        colors = []
        for s in signs:
            if s >= 0:
                colors.append(scen["color"]) # Real Phase
            else:
                colors.append('orange') # Branching Phase (Standard for all)
                
        lc = LineCollection(segments, colors=colors, linewidths=3)
        ax.add_collection(lc)
        # ax.plot(y,t)
        # Plot styling
        ax.set_title(scen["name"], fontsize=14, fontweight='bold')
        ax.set_xlabel("Time (t)")
        if i == 0: ax.set_ylabel("Spatial Position (y)")
        ax.grid(True, alpha=0.3)
        ax.autoscale()
        
        # Annotations
        if i == 0:
            ax.text(0.5, A+0.5, "Manifest Phase\n(Real)", color='green', ha='center', fontweight='bold')
            ax.text(0.9, -A-0.5, "Branching Phase\n(Hidden)", color='orange', ha='center', fontweight='bold')
        elif i == 1:
             ax.text(0.5, 3, "Manifest Phase Stretches\n(Time Dilation)", color='blue', ha='center')
             ax.text(1.0, 3, "Branching is Tiny\n(Stitch Point)", color='orange', ha='center', fontsize=8)
        elif i == 2:
             ax.text(0.5, 6, "Slope too steep!", color='red', ha='center')
             ax.text(1.0, 5, "No 'Down' Phase\nThread Snaps", color='red', ha='center')

    plt.suptitle("The Three States of Topological Stitching", fontsize=16, y=1.05)
    plt.tight_layout()
    plt.savefig('stitch_scenarios_viz.png')

if __name__ == "__main__":
    visualize_stitch_scenarios()
# Out:
# [0.         0.03144608 0.06288438 0.09430714 0.12570658 0.15707494
#  0.18840447 0.21968742 0.25091606 0.28208266 0.31317953 0.34419897
#  0.37513331 0.4059749  0.43671613 0.46734939 0.49786711 0.52826174
#  0.55852577 0.58865171 0.61863212 0.64845959 0.67812674 0.70762624
#  0.73695079 0.76609315 0.7950461  0.8238025  0.85235522 0.88069723
#  0.90882149 0.93672107 0.96438907 0.99181864 1.019003   1.04593544
#  1.07260929 1.09901796 1.12515492 1.15101371 1.17658793 1.20187127
#  1.22685747 1.25154035 1.27591382 1.29997185 1.32370848 1.34711785
#  1.37019418 1.39293176]
# [12.56637061 12.56481723 12.56015745 12.55239243 12.5415241  12.52755514
#  12.51048899 12.49032989 12.46708281 12.44075351 12.41134849 12.37887502
#  12.34334113 12.3047556  12.26312798 12.21846856 12.17078837 12.12009921
#  12.06641361 12.00974483 11.9501069  11.88751455 11.82198325 11.75352922
#  11.68216938 11.60792135 11.53080352 11.45083492 11.36803535 11.28242527
#  11.19402584 11.10285892 11.00894705 10.91231345 10.812982   10.71097727
#  10.60632447 10.49904948 10.38917882 10.27673965 10.16175976 10.04426759
#   9.92429219  9.80186321  9.67701093  9.5497662   9.42016049  9.28822584
#   9.15399488  9.01750077]
# [0.         0.05974871 0.11948965 0.17921505 0.23891713 0.29858813
#  0.35822029 0.41780588 0.47733715 0.53680639 0.59620589 0.65552797
#  0.71476494 0.77390918 0.83295304 0.89188894 0.95070929 1.00940656
#  1.06797322 1.1264018  1.18468485 1.24281496 1.30078474 1.35858688
#  1.41621407 1.47365906 1.53091465 1.58797368 1.64482905 1.70147368
#  1.75790059 1.8141028  1.87007344 1.92580564 1.98129264 2.03652771
#  2.0915042  2.14621551 2.2006551  2.25481653 2.30869339 2.36227937
#  2.4155682  2.46855372 2.52122983 2.57359049 2.62562976 2.67734177
#  2.72872073 2.77976095]
# [23.87610417 23.87455078 23.869891   23.86212599 23.85125765 23.83728869
#  23.82022255 23.80006344 23.77681637 23.75048706 23.72108204 23.68860857
#  23.65307468 23.61448916 23.57286154 23.52820211 23.48052192 23.42983276
#  23.37614716 23.31947838 23.25984045 23.1972481  23.13171681 23.06326278
#  22.99190293 22.91765491 22.84053707 22.76056848 22.67776891 22.59215882
#  22.50375939 22.41259248 22.31868061 22.222047   22.12271556 22.02071083
#  21.91605803 21.80878303 21.69891237 21.5864732  21.47149332 21.35400115
#  21.23402574 21.11159676 20.98674448 20.85949975 20.72989404 20.5979594
#  20.46372843 20.32723433]
# [0.         0.06918293 0.13835808 0.20751768 0.27665397 0.34575919
#  0.41482556 0.48384536 0.55281085 0.6217143  0.69054802 0.7593043
#  0.82797549 0.89655394 0.96503201 1.03340212 1.10165669 1.16978817
#  1.23778904 1.30565184 1.3733691  1.44093341 1.50833741 1.57557376
#  1.64263516 1.70951436 1.77620417 1.84269741 1.90898699 1.97506584
#  2.04092695 2.10656338 2.17196823 2.23713464 2.30205586 2.36672514
#  2.43113584 2.49528136 2.55915517 2.6227508  2.68606188 2.74908206
#  2.81180511 2.87422485 2.93633516 2.99813004 3.05960352 3.12074974
#  3.18156292 3.24203734]
# [27.64601535 27.64446196 27.63980219 27.63203717 27.62116884 27.60719987
#  27.59013373 27.56997463 27.54672755 27.52039825 27.49099322 27.45851975
#  27.42298586 27.38440034 27.34277272 27.2981133  27.25043311 27.19974395
#  27.14605834 27.08938957 27.02975163 26.96715928 26.90162799 26.83317396
#  26.76181411 26.68756609 26.61044825 26.53047966 26.44768009 26.36207001
#  26.27367058 26.18250366 26.08859179 25.99195819 25.89262674 25.79062201
#  25.68596921 25.57869422 25.46882356 25.35638438 25.2414045  25.12391233
#  25.00393693 24.88150795 24.75665566 24.62941094 24.49980523 24.36787058
#  24.23363961 24.09714551]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import LinearSegmentedColormap

class CausalStitchingLab:
    """
    The Causal Stitching Laboratory
    -------------------------------
    A suite of simulations to validate the Causal Bundle & Topological Time-Stitching Theory.
    
    Modules:
    1. visualize_topology: Shows the Phase Space loop and the 'Stitch'.
    2. simulate_bundle: Shows the 'Fiber Optic' nature of particles and Pruning.
    3. scan_resonance: Maps the Frequency/Slope quantization bands.
    4. check_relativity: Verifies the Pi-Convergence with Time Dilation.
    5. show_scenarios: Visualizes Rest vs Light Speed vs Instability.
    """

    def __init__(self):
        # Global Constants for the Universe Model
        self.C = 1.0  # Speed of Light
        self.RESONANCE_FREQ = 0.619885
        print("--- Causal Stitching Laboratory Initialized ---")

    def visualize_topology(self):
        """
        Visualizes the 'Stitching' mechanism in Phase Space.
        Demonstrates how a linear path creates a closed loop in the processor.
        """
        print("\nRunning: Topological Phase Space Visualization...")
        AMPLITUDE = 2.0
        FREQUENCY = self.RESONANCE_FREQ
        WAVE_SPEED = 1.0
        NUM_CYCLES = 6
        SLOPE_DEGREES = 45.0

        wavelength = WAVE_SPEED / FREQUENCY
        k = 2 * np.pi / wavelength
        slope_m = np.tan(np.deg2rad(SLOPE_DEGREES))
        x_max = NUM_CYCLES * wavelength
        t = np.linspace(0, x_max, 5000)
        
        # Master Equation: y = A*sin(kt) + mt
        y = AMPLITUDE * np.sin(k * t) + slope_m * t
        y_prime = AMPLITUDE * k * np.cos(k * t) + slope_m

        fig = plt.figure(figsize=(14, 10))
        
        # Plot 1: The Linear Wave
        ax1 = fig.add_subplot(2, 2, 1)
        points = np.array([t, y]).T.reshape(-1, 1, 2)
        segments = np.concatenate([points[:-1], points[1:]], axis=1)
        norm = plt.Normalize(-1, 1)
        lc = LineCollection(segments, cmap='coolwarm_r', norm=norm)
        lc.set_array(np.sign(y_prime[:-1]))
        lc.set_linewidth(2)
        ax1.add_collection(lc)
        ax1.autoscale_view()
        ax1.set_title(f"The Causal Wave (f={FREQUENCY})")
        ax1.set_xlabel("Time"); ax1.set_ylabel("State")

        # Plot 2: Phase Space (Detrended)
        ax2 = fig.add_subplot(2, 2, 2)
        detrended_y = AMPLITUDE * np.sin(k * t)
        ax2.plot(detrended_y, y_prime, color='purple')
        ax2.axhline(0, color='red', linestyle='--', label="Event Horizon")
        ax2.set_title("Phase Space: The Closed Loop Engine")
        ax2.set_xlabel("Position (Detrended)"); ax2.set_ylabel("Processing Speed (y')")
        ax2.legend()

        plt.tight_layout()
        plt.show()

    def simulate_bundle(self):
        """
        Visualizes the 'Bundle of Threads' and Probabilistic Pruning.
        Shows how 'Delay Choice' and 'Entanglement' work via filtering.
        """
        print("\nRunning: Bundle Interaction Simulation...")
        NUM_THREADS = 100
        NUM_STEPS = 500
        AMPLITUDE = 1.5
        k = 2 * np.pi * self.RESONANCE_FREQ
        t = np.linspace(0, 12, NUM_STEPS)
        
        # Generate threads with slight dispersion
        thread_offsets = np.random.normal(0, 0.4, NUM_THREADS)
        all_paths = np.zeros((NUM_THREADS, NUM_STEPS))
        for i in range(NUM_THREADS):
            all_paths[i, :] = AMPLITUDE * np.sin(k * t) + t + thread_offsets[i]

        # Interaction Event
        INTERACTION_IDX = 250
        TARGET_POS = all_paths[0, INTERACTION_IDX] # Center
        WIDTH = 0.5
        
        weights = np.ones(NUM_THREADS)
        
        # Calculate survival weight based on proximity to interaction
        for i in range(NUM_THREADS):
            dist = abs(all_paths[i, INTERACTION_IDX] - TARGET_POS)
            weights[i] = np.exp(- (dist**2) / (2 * WIDTH**2))

        fig, ax = plt.subplots(figsize=(14, 6))
        ax.set_facecolor('#1e1e1e')
        
        for i in range(NUM_THREADS):
            # Plot Past (Full Brightness)
            ax.plot(t[:INTERACTION_IDX], all_paths[i, :INTERACTION_IDX], 
                    color='cyan', alpha=0.1, lw=1)
            # Plot Future (Pruned Brightness)
            if weights[i] > 0.01:
                ax.plot(t[INTERACTION_IDX:], all_paths[i, INTERACTION_IDX:], 
                        color='cyan', alpha=0.1 * weights[i], lw=1)
                
        ax.scatter(t[INTERACTION_IDX], TARGET_POS, s=200, color='white', edgecolors='red', zorder=10)
        ax.set_title("The Bundle: Pruning of Invalid Threads")
        plt.show()

    def check_relativity(self):
        """
        The Pi-Convergence Test.
        Checks if the Geometric Stitch Ratio scales with Einstein's Gamma.
        """
        print("\nRunning: Relativity Calibration Check...")
        velocities = np.linspace(0.0, 0.99999999999 * self.C, 1000)
        gammas = []
        ratios = []

        for v in velocities:
            # Einstein
            gamma = 1 / np.sqrt(1 - (v**2 / self.C**2))
            gammas.append(gamma)
            
            # Geometric Stitch
            # Logic: cos(theta) = -v/c
            val = -v / self.C
            theta = np.arccos(val)
            real_angle = 2 * theta
            branching_angle = 2 * (np.pi - theta)
            ratio = real_angle / branching_angle
            ratios.append(ratio)

        gammas = np.array(gammas)
        ratios = np.array(ratios)
        scaling_factor = ratios / gammas
        final_factor = scaling_factor[-1]

        print(f"--- RESULTS ---")
        print(f"Convergence Factor at v->c: {final_factor:.5f}")
        print(f"Target (PI): {np.pi:.5f}")
        print(f"Match: {abs(final_factor - np.pi) < 0.001}")

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
        
        ax1.loglog(gammas, ratios, 'r-', lw=3, label='Geometric Ratio')
        ax1.loglog(gammas, gammas * np.pi, 'k--', label='Gamma * PI')
        ax1.set_title("Power Law Check")
        ax1.set_xlabel("Einstein Gamma"); ax1.set_ylabel("Stitch Ratio")
        ax1.legend()
        
        ax2.plot(velocities, scaling_factor, 'g-')
        ax2.axhline(np.pi, color='k', ls='--')
        ax2.set_title(f"The 'Hidden Factor' (Converges to {final_factor:.4f})")
        ax2.set_xlabel("Velocity v/c")
        
        plt.tight_layout()
        plt.show()

    def show_scenarios(self):
        """
        Visualizes the 3 states: Rest, Light Speed, Instability.
        """
        print("\nRunning: Scenario Visualization...")
        A = 1.0; k = 2 * np.pi
        t = np.linspace(0, 2.5, 1000)
        max_slope = A * k
        
        scenarios = [
            {"name": "Rest (Mass)", "m": 0.0},
            {"name": "Light Speed (Time Dilation)", "m": 0.95 * max_slope},
            {"name": "Instability (Broken Stitch)", "m": 1.2 * max_slope}
        ]
        
        fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
        for i, scen in enumerate(scenarios):
            m = scen["m"]
            y = A * np.sin(k * t) + m * t
            y_prime = A * k * np.cos(k * t) + m
            
            # Color segments
            points = np.array([t, y]).T.reshape(-1, 1, 2)
            segments = np.concatenate([points[:-1], points[1:]], axis=1)
            colors = ['blue' if yp >= 0 else 'orange' for yp in y_prime[:-1]]
            
            lc = LineCollection(segments, colors=colors, lw=2)
            axes[i].add_collection(lc)
            axes[i].set_title(scen["name"])
            axes[i].grid(True, alpha=0.3)
            axes[i].autoscale()
            
        plt.suptitle("Blue = Manifest Phase | Orange = Branching Phase")
        plt.tight_layout()
        plt.show()

if __name__ == "__main__":
    lab = CausalStitchingLab()
    
    # Uncomment the simulation you want to run:
    # lab.visualize_topology()
    # lab.simulate_bundle()
    lab.check_relativity()
    # lab.show_scenarios()
# Out:
# --- Causal Stitching Laboratory Initialized ---
#
# Running: Relativity Calibration Check...
# --- RESULTS ---
# Convergence Factor at v->c: 3.14159
# Target (PI): 3.14159
# Match: True

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

class GravityTopologyLab:
    """
    Visualizes the mechanical effect of Gravity on the Causal Stitch.
    Based on the Equivalence Principle:
    A stationary clock at radius r experiences an 'Effective Drift' (m)
    equal to the Escape Velocity at that height.
    """
    
    def __init__(self):
        self.C = 1.0
        self.Rs = 1.0 # Schwarzschild Radius
        self.A_base = 1.0 # Base Amplitude in free space
        self.k = 2 * np.pi # Base Frequency
    
    def visualize_gravity_topology(self):
        """
        Shows the Phase Space Loop (The 'Engine') at different depths in the gravity well.
        As we go deeper, the loop gets distorted, making the 'Stitch' harder to close.
        """
        print("\nRunning: Gravity Phase Space Topology...")
        
        # Define 3 locations
        locations = [
            {"name": "Deep Space (r = ∞)", "r": 1000.0},
            {"name": "Strong Gravity (r = 2 Rs)", "r": 2.0},
            {"name": "Event Horizon (r -> Rs)", "r": 1.001}
        ]
        
        fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
        
        t = np.linspace(0, 4, 2000)
        
        for i, loc in enumerate(locations):
            r = loc["r"] * self.Rs
            
            # Calculate Effective Drift (Escape Velocity)
            # This is the "Wind" of gravity blowing on the stitch
            if loc["r"] > 500:
                v_esc = 0
            else:
                v_esc = self.C * np.sqrt(self.Rs / r)
            
            # The Stitch Parameters
            # Amplitude A scales to keep Max Slope = C
            # In this visualization, we assume the internal engine runs at C.
            # So Amplitude is fixed, but the Drift m fights it.
            
            m = v_esc # The drift caused by gravity
            A = self.A_base
            
            # Master Equation
            y = A * np.sin(self.k * t) # Detrended position for Phase Space
            y_prime = A * self.k * np.cos(self.k * t) + m # Velocity includes drift
            
            # Plot Phase Space (y vs y')
            # Color logic: Red = Branching (Backswing), Blue = Real
            
            points = np.array([y, y_prime]).T.reshape(-1, 1, 2)
            segments = np.concatenate([points[:-1], points[1:]], axis=1)
            
            # Color by derivative sign relative to 0
            # Note: y_prime here is the TOTAL velocity. 
            # The Stitch happens when TOTAL velocity < 0.
            
            colors = ['orange' if yp < 0 else 'blue' for yp in y_prime[:-1]]
            
            lc = LineCollection(segments, colors=colors, linewidths=2)
            axes[i].add_collection(lc)
            
            # The Event Horizon Line (y' = 0)
            axes[i].axhline(0, color='red', linestyle='--', alpha=0.5, label='Stitch Horizon')
            
            axes[i].set_title(f"{loc['name']}\nEff. Drift v = {v_esc:.2f}c")
            axes[i].set_xlabel("Phase Position (y)")
            if i == 0: axes[i].set_ylabel("Processing Speed (y')")
            axes[i].grid(True, alpha=0.3)
            axes[i].autoscale()
            
            # Annotations
            if i == 0:
                axes[i].text(0, -A*self.k/2, "Large Backswing\n(Easy Stitch)", ha='center', color='orange')
            if i == 2:
                axes[i].text(0, 1, "Loop Lifted Up\n(Stitch Vanishing)", ha='center', color='blue')

        plt.suptitle("The Geometry of Gravity: Phase Space Distortion", fontsize=16)
        plt.tight_layout()
        plt.show()

    def show_gravity_scenarios(self):
        """
        Shows the Wave History (Time vs State) for a stationary clock 
        at different gravitational depths.
        This visualizes WHY time slows down: The 'Real' phase stretches out.
        """
        print("\nRunning: Gravity Wave Scenarios...")
        
        locations = [
            {"name": "Free Space Clock", "r": 1000.0},
            {"name": "GPS Satellite", "r": 5.0},
            {"name": "Near Event Horizon", "r": 1.01}
        ]
        
        fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
        t = np.linspace(0, 3, 1000)
        
        for i, loc in enumerate(locations):
            r = loc["r"] * self.Rs
            
            # Effective Drift
            if loc["r"] > 500: v_esc = 0
            else: v_esc = self.C * np.sqrt(self.Rs / r)
            
            m = v_esc
            A = self.A_base
            
            # Wave Equation: y = A sin(kt) + mt
            y = A * np.sin(self.k * t) + m * t
            y_prime = A * self.k * np.cos(self.k * t) + m
            
            points = np.array([t, y]).T.reshape(-1, 1, 2)
            segments = np.concatenate([points[:-1], points[1:]], axis=1)
            colors = ['orange' if yp < 0 else 'blue' for yp in y_prime[:-1]]
            
            lc = LineCollection(segments, colors=colors, linewidths=3)
            axes[i].add_collection(lc)
            
            axes[i].set_title(f"{loc['name']}")
            axes[i].set_xlabel("Time (t)")
            if i == 0: axes[i].set_ylabel("State (y)")
            axes[i].grid(True, alpha=0.3)
            axes[i].autoscale()
            
            # Calculate Duty Cycle for display
            # Ratio of Blue pixels to Orange pixels
            blue_count = np.sum(y_prime > 0)
            orange_count = np.sum(y_prime < 0)
            if orange_count > 0:
                ratio = blue_count / orange_count
                axes[i].text(0.5, 0.1, f"Stitch Ratio: {ratio:.1f}", transform=axes[i].transAxes, 
                             ha='center', bbox=dict(facecolor='white', alpha=0.8))
            else:
                axes[i].text(0.5, 0.1, f"Stitch Ratio: ∞ (Time Stop)", transform=axes[i].transAxes, 
                             ha='center', bbox=dict(facecolor='white', alpha=0.8))

        plt.suptitle("Gravitational Time Dilation: The Stretching of Reality", fontsize=16)
        plt.tight_layout()
        plt.show()

if __name__ == "__main__":
    lab = GravityTopologyLab()
    lab.visualize_gravity_topology()
    lab.show_gravity_scenarios()
# Out:
# Running: Gravity Phase Space Topology...
# Running: Gravity Wave Scenarios...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

class GravityTopologyLab:
    """
    Visualizes the mechanical effect of Gravity on the Causal Stitch.
    Based on the Equivalence Principle:
    A stationary clock at radius r experiences an 'Effective Drift' (m)
    equal to the Escape Velocity at that height.
    """
    
    def __init__(self):
        self.C = 1.0
        self.Rs = 1.0 # Schwarzschild Radius
        self.A_base = 1.0 # Base Amplitude in free space
        self.k = 2 * np.pi # Base Frequency
    
    def visualize_gravity_topology(self):
        """
        Shows the Phase Space Loop (The 'Engine') at different depths in the gravity well.
        As we go deeper, the loop gets distorted, making the 'Stitch' harder to close.
        """
        print("\nRunning: Gravity Phase Space Topology (Strict Mode)...")
        
        # Define 3 locations
        locations = [
            {"name": "Deep Space (r = ∞)", "r": 1000.0},
            {"name": "Strong Gravity (r = 2 Rs)", "r": 2.0},
            {"name": "Event Horizon (r -> Rs)", "r": 1.001}
        ]
        
        fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
        
        t = np.linspace(0, 4, 2000)
        
        for i, loc in enumerate(locations):
            r = loc["r"] * self.Rs
            
            # Calculate Effective Drift (Escape Velocity)
            # This is the "Wind" of gravity blowing on the stitch
            if loc["r"] > 500:
                v_esc = 0
            else:
                v_esc = self.C * np.sqrt(self.Rs / r)
            
            # The Stitch Parameters
            # Amplitude A scales to keep Max Slope = C
            # STRICT MODE: Enforce A = c/k so internal engine speed limit is C.
            # This makes the struggle against gravity critical.
            
            m = v_esc # The drift caused by gravity
            A = self.C / self.k # Strict Mode Enforced
            
            # Master Equation
            y = A * np.sin(self.k * t) # Detrended position for Phase Space
            y_prime = A * self.k * np.cos(self.k * t) + m # Velocity includes drift
            
            # Plot Phase Space (y vs y')
            # Color logic: Red = Branching (Backswing), Blue = Real
            
            points = np.array([y, y_prime]).T.reshape(-1, 1, 2)
            segments = np.concatenate([points[:-1], points[1:]], axis=1)
            
            # Color by derivative sign relative to 0
            # Note: y_prime here is the TOTAL velocity. 
            # The Stitch happens when TOTAL velocity < 0.
            
            colors = ['orange' if yp < 0 else 'blue' for yp in y_prime[:-1]]
            
            lc = LineCollection(segments, colors=colors, linewidths=2)
            axes[i].add_collection(lc)
            
            # The Event Horizon Line (y' = 0)
            axes[i].axhline(0, color='red', linestyle='--', alpha=0.5, label='Stitch Horizon')
            
            axes[i].set_title(f"{loc['name']}\nEff. Drift v = {v_esc:.2f}c")
            axes[i].set_xlabel("Phase Position (y)")
            if i == 0: axes[i].set_ylabel("Processing Speed (y')")
            axes[i].grid(True, alpha=0.3)
            axes[i].autoscale()
            
            # Annotations
            if i == 0:
                axes[i].text(0, -A*self.k/2, "Large Backswing\n(Easy Stitch)", ha='center', color='orange')
            if i == 2:
                axes[i].text(0, A*self.k*0.2, "Loop Lifted Up\n(Stitch Vanishing)", ha='center', color='blue')

        plt.suptitle("The Geometry of Gravity: Phase Space Distortion (Strict Mode)", fontsize=16)
        plt.tight_layout()
        plt.show()

    def show_gravity_scenarios(self):
        """
        Shows the Wave History (Time vs State) for a stationary clock 
        at different gravitational depths.
        This visualizes WHY time slows down: The 'Real' phase stretches out.
        """
        print("\nRunning: Gravity Wave Scenarios (Strict Mode)...")
        
        locations = [
            {"name": "Free Space Clock", "r": 1000.0},
            {"name": "GPS Satellite", "r": 5.0},
            {"name": "Near Event Horizon", "r": 1.01}
        ]
        
        fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
        t = np.linspace(0, 3, 1000)
        
        for i, loc in enumerate(locations):
            r = loc["r"] * self.Rs
            
            # Effective Drift
            if loc["r"] > 500: v_esc = 0
            else: v_esc = self.C * np.sqrt(self.Rs / r)
            
            m = v_esc
            # Strict Mode Enforced: A = c/k
            A = self.C / self.k
            
            # Wave Equation: y = A sin(kt) + mt
            y = A * np.sin(self.k * t) + m * t
            y_prime = A * self.k * np.cos(self.k * t) + m
            
            points = np.array([t, y]).T.reshape(-1, 1, 2)
            segments = np.concatenate([points[:-1], points[1:]], axis=1)
            colors = ['orange' if yp < 0 else 'blue' for yp in y_prime[:-1]]
            
            lc = LineCollection(segments, colors=colors, linewidths=3)
            axes[i].add_collection(lc)
            
            axes[i].set_title(f"{loc['name']}")
            axes[i].set_xlabel("Time (t)")
            if i == 0: axes[i].set_ylabel("State (y)")
            axes[i].grid(True, alpha=0.3)
            axes[i].autoscale()
            
            # Calculate Duty Cycle for display
            # Ratio of Blue pixels to Orange pixels
            blue_count = np.sum(y_prime > 0)
            orange_count = np.sum(y_prime < 0)
            if orange_count > 0:
                ratio = blue_count / orange_count
                axes[i].text(0.5, 0.1, f"Stitch Ratio: {ratio:.1f}", transform=axes[i].transAxes, 
                             ha='center', bbox=dict(facecolor='white', alpha=0.8))
            else:
                axes[i].text(0.5, 0.1, f"Stitch Ratio: ∞ (Time Stop)", transform=axes[i].transAxes, 
                             ha='center', bbox=dict(facecolor='white', alpha=0.8))

        plt.suptitle("Gravitational Time Dilation: Strict Mode (A = c/k)", fontsize=16)
        plt.tight_layout()
        plt.show()

if __name__ == "__main__":
    lab = GravityTopologyLab()
    lab.visualize_gravity_topology()
    lab.show_gravity_scenarios()
# Out:
# Running: Gravity Phase Space Topology (Strict Mode)...
# Running: Gravity Wave Scenarios (Strict Mode)...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

class GravityRiverModel:
    """
    Visualizes the 'River Model' of Gravity.
    
    Concept:
    1. Space is not static; it flows into mass (The River).
    2. A 'Stationary' particle is like a swimmer maintaining position against the current.
    3. The 'Drift' (m) in our Stitching Equation is simply the speed of the current.
    """
    
    def __init__(self):
        self.C = 1.0
        self.Rs = 1.0 # Schwarzschild Radius
        
    def visualize_river_mechanics(self):
        print("\nRunning: Gravity River Visualization...")
        
        # --- 1. Setup the River Field ---
        # Distance r from the Black Hole (at r=0)
        r = np.linspace(1.0, 10.0, 100) * self.Rs
        
        # Velocity of the River (Inward Flow)
        # v_flow = -c * sqrt(Rs/r) (Negative because it falls IN)
        v_flow = -self.C * np.sqrt(self.Rs / r)
        
        # --- 2. Setup the Swimmer (The Particle) ---
        # We place a particle at r = 4 Rs
        particle_r = 4.0 * self.Rs
        particle_v_flow = -self.C * np.sqrt(self.Rs / particle_r)
        
        # To stay stationary (dr/dt = 0), the particle must swim OUT at v_swim = -v_flow
        v_swim = -particle_v_flow
        
        print(f"Particle at r={particle_r:.1f}Rs")
        print(f"River Speed: {particle_v_flow:.2f}c")
        print(f"Required Swim Speed (Drift m): {v_swim:.2f}c")

        # --- 3. Visualization ---
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        # Plot 1: The Velocity Field (The River)
        ax1.plot(r, v_flow, 'b-', linewidth=2, label='River Velocity (Space Flow)')
        ax1.axhline(0, color='gray', linestyle=':')
        ax1.axvline(self.Rs, color='k', linestyle='--', label='Event Horizon')
        
        # Draw the Particle Swimmer
        ax1.scatter(particle_r, particle_v_flow, s=200, color='lime', zorder=10, label='Particle Location')
        
        # Draw vectors to show the struggle
        # River Vector (Downstream)
        ax1.arrow(particle_r, 0, 0, particle_v_flow, 
                  head_width=0.2, head_length=0.1, fc='blue', ec='blue', length_includes_head=True)
        ax1.text(particle_r + 0.2, particle_v_flow/2, "River Flow", color='blue')
        
        # Swim Vector (Upstream)
        ax1.arrow(particle_r, particle_v_flow, 0, -particle_v_flow, 
                  head_width=0.2, head_length=0.1, fc='lime', ec='lime', length_includes_head=True)
        ax1.text(particle_r + 0.2, particle_v_flow/2 + 0.2, "Swim (Drift m)", color='green')
        
        ax1.set_title("The River of Space: Inward Flow Velocity", fontsize=14)
        ax1.set_xlabel("Distance from Singularity (r)")
        ax1.set_ylabel("Flow Velocity (v/c)")
        ax1.invert_xaxis()
        ax1.legend()
        ax1.grid(True, alpha=0.3)
        
        # Plot 2: The Stitching Consequence (The Master Equation)
        # Show how this 'Swim' becomes the 'Drift' in phase space
        
        t = np.linspace(0, 3, 1000)
        k = 2 * np.pi
        A = self.C / k # Strict Mode
        m = v_swim # The swim speed IS the drift m
        
        # Wave function in the Swimmer's Frame
        # y = A sin(kt) + mt
        y = A * np.sin(k * t) + m * t
        
        # Calculate derivative to color the stitch
        y_prime = A * k * np.cos(k * t) + m
        
        points = np.array([t, y]).T.reshape(-1, 1, 2)
        segments = np.concatenate([points[:-1], points[1:]], axis=1)
        colors = ['orange' if yp < 0 else 'blue' for yp in y_prime[:-1]]
        
        lc = LineCollection(segments, colors=colors, linewidths=3)
        ax2.add_collection(lc)
        ax2.set_xlim(0, 3)
        ax2.set_ylim(np.min(y), np.max(y))
        
        ax2.set_title(f"The Resulting Stitch (Drift m = {m:.2f}c)", fontsize=14)
        ax2.set_xlabel("Time (t)")
        ax2.set_ylabel("Phase Position")
        ax2.grid(True, alpha=0.3)
        
        # Annotations for ratio
        blue_len = np.sum(y_prime > 0)
        orange_len = np.sum(y_prime < 0)
        ratio = blue_len / orange_len
        ax2.text(0.1, 0.8, f"Stitch Ratio: {ratio:.2f}", transform=ax2.transAxes, 
                 bbox=dict(facecolor='white', alpha=0.8))
        
        plt.tight_layout()
        plt.savefig('gravity_river_viz.png')
        print("Visualization saved to gravity_river_viz.png")

if __name__ == "__main__":
    river = GravityRiverModel()
    river.visualize_river_mechanics()
# Out:
# Running: Gravity River Visualization...
# Particle at r=4.0Rs
# River Speed: -0.50c
# Required Swim Speed (Drift m): 0.50c
# Visualization saved to gravity_river_viz.png

# %%
import numpy as np
from scipy.optimize import fsolve

def calculate_quantized_drifts():
    """
    Solves the 'Strict Mode' Resonance Equation.
    
    Constraint: A = c/omega (Strict Mode)
    Result: Omega cancels out. The equation constrains Drift 'm'.
    
    Equation: sqrt(1 - m^2) = m * (pi * N - arccos(-m))
    (assuming c=1)
    """
    
    def strict_resonance_eq(m, N):
        # LHS: Vertical drop of the wave
        lhs = np.sqrt(1 - m**2)
        
        # RHS: Vertical rise of the drift over N cycles
        # Phase duration = 2*pi*N - 2*arccos(-m)
        rhs = m * (np.pi * N - np.arccos(-m))
        
        return lhs - RHS
    
    print("--- Quantized Drift Velocities (Strict Mode) ---")
    print("N | Allowed Drift (v/c)")
    print("-" * 30)
    
    solutions = []
    
    for N in range(1, 11):
        # Define the error function for this N
        func = lambda m: np.sqrt(1 - m**2) - m * (np.pi * N - np.arccos(-m))
        
        # Initial guess: For large N, m is small. m ~ 1/N
        guess = 1.0 / (np.pi * N)
        
        # Solve
        m_sol = fsolve(func, guess)[0]
        solutions.append((N, m_sol))
        
        print(f"{N} | {m_sol:.8f}")

    return solutions

if __name__ == "__main__":
    calculate_quantized_drifts()
# Out:
# --- Quantized Drift Velocities (Strict Mode) ---
# N | Allowed Drift (v/c)
# ------------------------------
# 1 | 1.00000000
# 2 | 0.21723363
# 3 | 0.12837455
# 4 | 0.09132520
# 5 | 0.07091346
# 6 | 0.05797180
# 7 | 0.04902962
# 8 | 0.04247962
# 9 | 0.03747452
# 10 | 0.03352514

# %%
import numpy as np
import matplotlib.pyplot as plt

def compare_stitch_models():
    """
    Compares the Scalar (1D) Stitch model against the Helical (3D) Stitch model
    to see which one reproduces Special Relativity correctly at low speeds.
    """
    C = 1.0
    velocities = np.linspace(0.0, 0.99 * C, 500)

    # 1. Einstein's Gamma (The Target)
    gammas = 1 / np.sqrt(1 - (velocities/C)**2)

    # 2. Scalar Stitch Ratio (The Linear Error Model)
    # Ratio = 2*theta / 2*(pi - theta), where cos(theta) = -v/c
    # This assumes the drift subtracts directly from the internal speed.
    scalar_ratios = []
    for v in velocities:
        val = -v / C
        theta = np.arccos(val)
        ratio = (2 * theta) / (2 * (np.pi - theta))
        scalar_ratios.append(ratio)

    # 3. Helical Stitch Ratio (The Vector Model)
    # Logic: The particle moves in a Helix.
    # Total Speed along the path must be C.
    # Total Velocity^2 = (Drift Velocity)^2 + (Internal Rotation Speed)^2
    # C^2 = v^2 + v_rot^2
    # Therefore, v_rot = sqrt(C^2 - v^2)
    #
    # The "Stitch" is completing one full internal rotation (2*pi*r).
    # Time to Stitch (T) = Circumference / v_rot
    # T = (2*pi*r) / sqrt(C^2 - v^2)
    #
    # At Rest (v=0): T0 = (2*pi*r) / C
    # Ratio = T / T0 = C / sqrt(C^2 - v^2)

    helical_ratios = []
    for v in velocities:
        # Avoid division by zero at c
        if v >= C:
            ratio = 100 # Infinity
        else:
            # The geometric derivation naturally produces Gamma
            ratio = C / np.sqrt(C**2 - v**2)
        helical_ratios.append(ratio)

    # --- Visualization ---
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    # Plot 1: Low Velocity / Newtonian Limit
    # We zoom in on v = 0 to 0.2c to see the "Linear Error" clearly
    limit_idx = int(len(velocities) * 0.2)

    ax1.plot(velocities[:limit_idx], scalar_ratios[:limit_idx], 'r-', linewidth=2, label='Scalar Stitch (1D)')
    ax1.plot(velocities[:limit_idx], helical_ratios[:limit_idx], 'g-', linewidth=3, alpha=0.7, label='Helical Stitch (3D)')
    ax1.plot(velocities[:limit_idx], gammas[:limit_idx], 'b--', linewidth=2, label='Einstein Gamma')

    ax1.set_title("Low Velocity Limit (v << c)", fontsize=14)
    ax1.set_xlabel("Velocity (v/c)")
    ax1.set_ylabel("Dilation Ratio")
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    ax1.text(0.05, 1.1, "Notice the Red line rises too fast (Linear).\nThe Green line matches Blue perfectly (Quadratic).",
             bbox=dict(facecolor='white', alpha=0.8))

    # Plot 2: High Velocity Limit
    ax2.plot(velocities, scalar_ratios, 'r-', linewidth=2, label='Scalar Stitch')
    ax2.plot(velocities, helical_ratios, 'g-', linewidth=4, alpha=0.6, label='Helical Stitch')
    ax2.plot(velocities, gammas, 'b--', linewidth=2, label='Einstein Gamma')

    ax2.set_title("Full Spectrum (v -> c)", fontsize=14)
    ax2.set_xlabel("Velocity (v/c)")
    ax2.set_ylabel("Dilation Ratio")
    ax2.set_yscale('log') # Log scale to see the divergence
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('helical_fix.png')
    print("Emulation Complete. The Helical Model should overlay Gamma perfectly.")

if __name__ == "__main__":
    compare_stitch_models()
# Out:
# Emulation Complete. The Helical Model should overlay Gamma perfectly.
